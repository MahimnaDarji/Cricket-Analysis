# %% [markdown]
# # Ganguly V/S Rohit Comparison

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('https://raw.githubusercontent.com/madaboutsports-mas/MAS-ACA-Masterclass/main/CSV%20Files/ODI_data.csv?token=GHSAT0AAAAAAB6PBHSOCTJ5DSQRFS26GDWGY77LILQ')

# %%
data.head(5)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0        E Lewis                  65                      65
# 1       N Pooran                  42                      42
# 2     SO Hetmyer                  18                      18
# 3       RL Chase                  18                      18
# 4    SS Cottrell                  17                      17
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    128                  1.0                   0.0
# 1                     69                  1.0                   0.0
# 2                     31                  1.0                   0.0
# 3                     34                  1.0                   0.0
# 4                     23                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                  80                      8                      1
# ...

# %%
data.shape
# Out:
# (171968, 28)

# %%
data.size
# Out:
# 4815104

# %%
data['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '-', nan, '40', '6', '4', '87', '54', '46',
#        '30', '12', '69', '39', '14', '10', '9', '8', '7', '82', '52',
#        '41', '15', '98', '43', '19', '111', '48', '36', '25', '67', '60',
#        '84', '59', '55', '47', '85', '49', '45', '34', '29', '22', '74',
#        '28', '77', '50', '32', '23', '35', '122', '100', '95', '103',
#        '113', '53', '96', '27', '64', '58', '33', '31', '73', '56', '86',
#        '62', '106', '24', '57', '104', '26', '66', '51', '118', '105',
#        '101', '21', '79', '44', '102', '88', '80', '72', '97', '68', '89',
#        '38', '83', '63', '148', '166', '90', '76', '37', '70', '124',
#        '94', '140', '153', '107', '117', '121', '92', '78', '75', '114',
#        '115', '130', '128', '151', '110', '138', '135', '109', '61',
#        '179', '170', '112', '116', '91', '143', '93', '123', '145', '81',
# ...

# %%
data=data[data['Innings Runs Scored Num'] != '-']

# %%
data['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', nan, '40', '6', '4', '87', '54', '46', '30',
#        '12', '69', '39', '14', '10', '9', '8', '7', '82', '52', '41',
#        '15', '98', '43', '19', '111', '48', '36', '25', '67', '60', '84',
#        '59', '55', '47', '85', '49', '45', '34', '29', '22', '74', '28',
#        '77', '50', '32', '23', '35', '122', '100', '95', '103', '113',
#        '53', '96', '27', '64', '58', '33', '31', '73', '56', '86', '62',
#        '106', '24', '57', '104', '26', '66', '51', '118', '105', '101',
#        '21', '79', '44', '102', '88', '80', '72', '97', '68', '89', '38',
#        '83', '63', '148', '166', '90', '76', '37', '70', '124', '94',
#        '140', '153', '107', '117', '121', '92', '78', '75', '114', '115',
#        '130', '128', '151', '110', '138', '135', '109', '61', '179',
#        '170', '112', '116', '91', '143', '93', '123', '145', '81', '150',
# ...

# %%
data=data.dropna(subset=['Innings Runs Scored Num'])

# %%
data['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '40', '6', '4', '87', '54', '46', '30', '12',
#        '69', '39', '14', '10', '9', '8', '7', '82', '52', '41', '15',
#        '98', '43', '19', '111', '48', '36', '25', '67', '60', '84', '59',
#        '55', '47', '85', '49', '45', '34', '29', '22', '74', '28', '77',
#        '50', '32', '23', '35', '122', '100', '95', '103', '113', '53',
#        '96', '27', '64', '58', '33', '31', '73', '56', '86', '62', '106',
#        '24', '57', '104', '26', '66', '51', '118', '105', '101', '21',
#        '79', '44', '102', '88', '80', '72', '97', '68', '89', '38', '83',
#        '63', '148', '166', '90', '76', '37', '70', '124', '94', '140',
#        '153', '107', '117', '121', '92', '78', '75', '114', '115', '130',
#        '128', '151', '110', '138', '135', '109', '61', '179', '170',
#        '112', '116', '91', '143', '93', '123', '145', '81', '150', '162',
# ...

# %%
data['Innings Date']=pd.to_datetime(data['Innings Date'])

# %%
data['Year']=data['Innings Date'].dt.year

# %%
data.head(2)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0        E Lewis                  65                      65
# 1       N Pooran                  42                      42
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    128                  1.0                   0.0
# 1                     69                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                  80                      8                      1
# 1                  52                      4                      1
#
#   Innings Batting Strike Rate  ... Innings Bowled Flag Innings Maidens Bowled  \
# 0                       81.25  ...                 NaN                    NaN
# 1                       80.76  ...                 NaN                    NaN
#
#   Innings Runs Conceded Innings Wickets Taken 4 Wickets  5 Wickets  \
# ...

# %%
data['Innings Runs Scored Num'] = data['Innings Runs Scored Num'].astype('int')

# %%
data['Innings Balls Faced'] = data['Innings Balls Faced'].astype('int')

# %%
data['Innings Not Out Flag'] = data['Innings Not Out Flag'].astype('float')

# %%
ganguly_data=data[(data.Year >= 1997) & (data.Year <= 2007)]

# %%
rohit_data=data[(data.Year >= 2009) & (data.Year <= 2019)]

# %%
rohit_data.head(2)
# Out:
#   Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 0        E Lewis                  65                       65
# 1       N Pooran                  42                       42
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    128                  1.0                     0
# 1                     69                  1.0                     0
#
#    Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                   80                      8                      1
# 1                   52                      4                      1
#
#   Innings Batting Strike Rate  ... Innings Bowled Flag Innings Maidens Bowled  \
# 0                       81.25  ...                 NaN                    NaN
# 1                       80.76  ...                 NaN                    NaN
#
#   Innings Runs Conceded Innings Wickets Taken 4 Wickets  5 Wickets  \
# ...

# %%
ganguly_data.tail(20)
# Out:
#         Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 121719      GD McGrath                   1                        1
# 121720      Ijaz Ahmed                  58                       58
# 121721    Aamer Sohail                  52                       52
# 121722   Shahid Afridi                  34                       34
# 121723       Moin Khan                 17*                       17
# 121724  Mohammad Wasim                 16*                       16
# 121725     Wasim Akram                  11                       11
# 121726  Inzamam-ul-Haq                   8                        8
# 121727    Zahoor Elahi                   0                        0
# 121731        A Flower                  63                       63
# 121732       HH Streak                 43*                       43
# 121733        CN Evans                  32                       32
# 121734    ADR Campbell                  14                       14
# ...

# %%
data.dtypes
# Out:
# Innings Player                           object
# Innings Runs Scored                      object
# Innings Runs Scored Num                   int32
# Innings Minutes Batted                   object
# Innings Batted Flag                     float64
# Innings Not Out Flag                      int32
# Innings Balls Faced                       int32
# Innings Boundary Fours                   object
# Innings Boundary Sixes                   object
# Innings Batting Strike Rate              object
# Innings Number                           object
# Opposition                               object
# Ground                                   object
# Innings Date                     datetime64[ns]
# Country                                  object
# 50's                                    float64
# 100's                                   float64
# Innings Runs Scored Buckets              object
# Innings Overs Bowled                     object
# Innings Bowled Flag                     float64
# ...

# %%
#For Ganguly
sg=ganguly_data[ganguly_data['Innings Player'] == 'SC Ganguly']

# %%
sg.head(5)
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 61054     SC Ganguly                   5                        5
# 61096     SC Ganguly                  39                       39
# 61145     SC Ganguly                   6                        6
# 61185     SC Ganguly                  39                       39
# 61464     SC Ganguly                   0                        0
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 61054                     11                  1.0                     0
# 61096                     79                  1.0                     0
# 61145                      2                  1.0                     0
# 61185                     87                  1.0                     0
# 61464                      9                  1.0                     0
#
#        Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# ...

# %%
#For Rohit Sharma
rg=rohit_data[rohit_data['Innings Player'] == 'RG Sharma']

# %%
rg.tail(5)
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 53169      RG Sharma                   4                        4
# 54043      RG Sharma                 43*                       43
# 54365      RG Sharma                  15                       15
# 54477      RG Sharma                  4*                        4
# 54783      RG Sharma                 25*                       25
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 53169                      9                  1.0                     0
# 54043                    106                  1.0                     1
# 54365                     31                  1.0                     0
# 54477                     12                  1.0                     1
# 54783                     44                  1.0                     1
#
#        Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# ...

# %%
#Runs Scored by Ganguly between 1997 to 2007
print("Total Runs of Ganguly",sum(sg['Innings Runs Scored Num']))
print("Total Inning of Ganguly",sum(sg['Innings Batted Flag']))
# Out:
# Total Runs of Ganguly 10949
# Total Inning of Ganguly 287.0

# %%
#Runs Scored by Rohit Sharma between 2009 to 2019
print("Total Runs of Rohit",sum(rg['Innings Runs Scored Num']))
print("Total Innings of Rohit",sum(rg['Innings Batted Flag']))
# Out:
# Total Runs of Rohit 8083
# Total Innings of Rohit 179.0

# %%
#Runs Per Innings of Both Ganguly and Rohit
print("RPI Of Ganguly",(sum(sg['Innings Runs Scored Num'])/sum(sg['Innings Batted Flag'])))
print("RPI Of Rohit",(sum(rg['Innings Runs Scored Num'])/sum(rg['Innings Batted Flag'])))
# Out:
# RPI Of Ganguly 38.149825783972126
# RPI Of Rohit 45.15642458100559

# %%
#Strike Rate of Both Ganguly and Rohit
print("Strike Rate of Ganguly",(100*(sum(sg['Innings Runs Scored Num']))/sum(sg['Innings Balls Faced'])))
print("Strike Rate of Rohit",(100*(sum(rg['Innings Runs Scored Num']))/sum(rg['Innings Balls Faced'])))
# Out:
# Strike Rate of Ganguly 74.01974040021634
# Strike Rate of Rohit 89.88101856999889

# %%
#No. Of Hundreds in their Peak and Innings Per Hundred
print("Hundreds of Ganguly",sum(sg["100's"]))
print("Hundreds of Rohit",sum(rg["100's"]))
print("Innings Per Hundred Of Ganguly",(sum(sg['Innings Batted Flag']))/sum(sg["100's"]))
print("Innings Per Hundred Of Rohit",(sum(rg['Innings Batted Flag']))/sum(rg["100's"]))
# Out:
# Hundreds of Ganguly 22.0
# Hundreds of Rohit 27.0
# Innings Per Hundred Of Ganguly 13.045454545454545
# Innings Per Hundred Of Rohit 6.62962962962963

# %%
#No. Of Fifties in their Peak and Innings Per Hundred
print("Fifties of Ganguly",sum(sg["50's"]))
print("Fifties of Rohit",sum(rg["50's"]))
print("Innings Per Fifties Of Ganguly",(sum(sg['Innings Batted Flag']))/sum(sg["50's"]))
print("Innings Per Fifties Of Rohit",(sum(rg['Innings Batted Flag']))/sum(rg["50's"]))
# Out:
# Fifties of Ganguly 69.0
# Fifties of Rohit 38.0
# Innings Per Fifties Of Ganguly 4.159420289855072
# Innings Per Fifties Of Rohit 4.7105263157894735

# %%
#Total Contribution of Ganguly in Teams Score
print("Total Team Runs",sum(ganguly_data[ganguly_data.Country == 'India']['Innings Runs Scored Num']))
print("Ganguly's Total Runs",sum(sg['Innings Runs Scored Num']))
print("Contribution Of Ganguly in Team's Run",(100*sum(sg['Innings Runs Scored Num']))/(sum(ganguly_data[ganguly_data.Country == 'India']['Innings Runs Scored Num'])),"%")
# Out:
# Total Team Runs 76149
# Ganguly's Total Runs 10949
# Contribution Of Ganguly in Team's Run 14.378389735912487 %

# %%
#Total Contribution of Rohit in Teams Score
print("Total Team Runs",sum(rohit_data[rohit_data.Country == 'India']['Innings Runs Scored Num']))
print("Rohit's Total Runs",sum(rg['Innings Runs Scored Num']))
print("Contribution Of Rohit in Team's Run",(100*sum(rg['Innings Runs Scored Num']))/(sum(rohit_data[rohit_data.Country == 'India']['Innings Runs Scored Num'])),"%")
# Out:
# Total Team Runs 63867
# Rohit's Total Runs 8083
# Contribution Of Rohit in Team's Run 12.655988225531182 %

# %%
# Average Number of Balls Faced per Innings
print("Average Number of Balls Faced by Ganguly",(sum(sg['Innings Balls Faced']))/sum(sg['Innings Batted Flag']))
print("Average Number of Balls Faced by Rohit",(sum(rg['Innings Balls Faced']))/sum(rg['Innings Batted Flag']))
# Out:
# Average Number of Balls Faced by Ganguly 51.54006968641115
# Average Number of Balls Faced by Rohit 50.24022346368715

# %% [markdown]
# # Visualization Part

# %%
#Other Top Runs Scorer during Ganguly's Time
ganguly_data.groupby(['Innings Player'])['Innings Runs Scored Num'].sum().sort_values(ascending = False).head(10)
# Out:
# Innings Player
# SR Tendulkar       11139
# SC Ganguly         10949
# R Dravid            9989
# RT Ponting          9791
# ST Jayasuriya       9531
# AC Gilchrist        9255
# JH Kallis           9010
# Mohammad Yousuf     8484
# MS Atapattu         8402
# Inzamam-ul-Haq      7892
# Name: Innings Runs Scored Num, dtype: int32

# %%
ganguly_data.groupby(['Innings Player'])['Innings Runs Scored Num'].sum().sort_values(ascending = False).head(10).plot(kind= 'barh')
plt.xlabel('Total Runs')
plt.ylabel('Player Name')
plt.show()

# %%
#Other Top Runs Scorer in Rohit's Time
rohit_data.groupby(['Innings Player'])['Innings Runs Scored Num'].sum().sort_values(ascending = False).head(10)
# Out:
# Innings Player
# V Kohli           11247
# RG Sharma          8083
# HM Amla            7745
# TM Dilshan         7296
# KC Sangakkara      7275
# AB de Villiers     7247
# LRPL Taylor        7059
# MS Dhoni           6838
# EJG Morgan         6748
# MJ Guptill         6626
# Name: Innings Runs Scored Num, dtype: int32

# %%
rohit_data.groupby(['Innings Player'])['Innings Runs Scored Num'].sum().sort_values(ascending = False).head(10).plot(kind = 'barh')
plt.xlabel('Total Runs')
plt.ylabel('Player Name')
plt.show()

# %%
#Ganguly's Runs Yearwise
sg.groupby(['Year'])['Innings Runs Scored Num'].sum()
# Out:
# Year
# 1997    1338
# 1998    1328
# 1999    1767
# 2000    1579
# 2001     813
# 2002    1114
# 2003     756
# 2004     947
# 2005     187
# 2007    1120
# Name: Innings Runs Scored Num, dtype: int32

# %%
sg.groupby(['Year'])['Innings Runs Scored Num'].sum().plot(kind='bar')
plt.ylabel('Total Runs')
plt.xlabel('Year')
plt.show()

# %%
#Rohit's Runs Yearwise
rg.groupby(['Year'])['Innings Runs Scored Num'].sum()
# Out:
# Year
# 2009     102
# 2010     504
# 2011     611
# 2012     168
# 2013    1196
# 2014     578
# 2015     815
# 2016     564
# 2017    1293
# 2018    1030
# 2019    1222
# Name: Innings Runs Scored Num, dtype: int32

# %%
rg.groupby(['Year'])['Innings Runs Scored Num'].sum().plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('Runs Scored')
plt.show()

# %%
#Most 100's in Ganguly's Time
ganguly_data.groupby(['Innings Player'])["100's"].sum().sort_values(ascending= False).head(10)
# Out:
# Innings Player
# SR Tendulkar       31.0
# RT Ponting         22.0
# SC Ganguly         22.0
# ST Jayasuriya      22.0
# HH Gibbs           19.0
# CH Gayle           15.0
# AC Gilchrist       15.0
# JH Kallis          15.0
# NJ Astle           13.0
# Mohammad Yousuf    13.0
# Name: 100's, dtype: float64

# %%
ganguly_data.groupby(['Innings Player'])["100's"].sum().sort_values(ascending= False).head(10).plot(kind='barh')
plt.xlabel('Total Centuries')
plt.ylabel('Player Name')
plt.show()

# %%
#Most 100's in Rohit's Time
rohit_data.groupby(['Innings Player'])["100's"].sum().sort_values(ascending=False).head(10)
# Out:
# Innings Player
# V Kohli           42.0
# RG Sharma         27.0
# HM Amla           26.0
# AB de Villiers    22.0
# TM Dilshan        21.0
# LRPL Taylor       17.0
# S Dhawan          17.0
# DA Warner         17.0
# MJ Guptill        16.0
# JE Root           16.0
# Name: 100's, dtype: float64

# %%
rohit_data.groupby(['Innings Player'])["100's"].sum().sort_values(ascending=False).head(10).plot(kind='barh')
plt.xlabel('Total Centuries')
plt.ylabel('Player Name')
plt.show()

# %%
#Most 50's in Ganguly's Time
ganguly_data.groupby(['Innings Player'])["50's"].sum().sort_values(ascending= False).head(10)
# Out:
# Innings Player
# R Dravid           77.0
# SC Ganguly         69.0
# JH Kallis          63.0
# MS Atapattu        58.0
# Mohammad Yousuf    58.0
# RT Ponting         58.0
# Inzamam-ul-Haq     57.0
# SR Tendulkar       56.0
# AC Gilchrist       53.0
# ST Jayasuriya      51.0
# Name: 50's, dtype: float64

# %%
ganguly_data.groupby(['Innings Player'])["50's"].sum().sort_values(ascending= False).head(10).plot(kind='bar')
plt.xlabel('Total Fifties')
plt.ylabel('Player Name')
plt.show()

# %%
#Most 50's in Rohit's Time
rohit_data.groupby(['Innings Player'])["50's"].sum().sort_values(ascending= False).head(10)
# Out:
# Innings Player
# V Kohli            53.0
# KC Sangakkara      50.0
# MS Dhoni           48.0
# LRPL Taylor        44.0
# EJG Morgan         43.0
# AD Mathews         40.0
# KS Williamson      39.0
# Tamim Iqbal        39.0
# Shakib Al Hasan    39.0
# AB de Villiers     39.0
# Name: 50's, dtype: float64

# %%
rohit_data.groupby(['Innings Player'])["50's"].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.xlabel('Total Fifties')
plt.ylabel('Player Name')
plt.show()

# %%
#Batters with Most Innings in Ganguly's Time
ganguly_data.groupby(['Innings Player'])['Innings Batted Flag'].sum().sort_values(ascending= False).head(10)
# Out:
# Innings Player
# SC Ganguly          287.0
# R Dravid            285.0
# ST Jayasuriya       275.0
# SR Tendulkar        266.0
# AC Gilchrist        266.0
# MS Atapattu         249.0
# RT Ponting          245.0
# DPMD Jayawardene    239.0
# JH Kallis           237.0
# Mohammad Yousuf     233.0
# Name: Innings Batted Flag, dtype: float64

# %%
ganguly_data.groupby(['Innings Player'])['Innings Batted Flag'].sum().sort_values(ascending= False).head(10).plot(kind='bar')
plt.xlabel('Total Innings')
plt.ylabel('Player Name')
plt.show()

# %%
#Batters with Most Innings in Rohit's Time
rohit_data.groupby(['Innings Player'])['Innings Batted Flag'].sum().sort_values(ascending= False).head(10)
# Out:
# Innings Player
# V Kohli            224.0
# EJG Morgan         196.0
# MS Dhoni           185.0
# AD Mathews         182.0
# RG Sharma          179.0
# MJ Guptill         176.0
# TM Dilshan         174.0
# HM Amla            169.0
# Mushfiqur Rahim    168.0
# LRPL Taylor        168.0
# Name: Innings Batted Flag, dtype: float64

# %%
rohit_data.groupby(['Innings Player'])['Innings Batted Flag'].sum().sort_values(ascending= False).head(10).plot(kind='bar')
plt.xlabel('Total Innings')
plt.ylabel('Player Name')
plt.show()

# %% [markdown]
# ## Conclusions:-
# ### Highest Runs Scored = Ganguly
# ### Highest Runs Per Innings = Rohit
# ### Highest Strike Rate = Rohit
# ### Most Number of 100's Scored = Rohit
# ### Minimum Number Of Innings per 100 = Rohit
# ### Most Number of 50's Scored = Ganguly
# ### Minimum Number Of Innings per 50 = Ganguly
# ### Better Contribution in Teams Score = Ganguly
# ### Number Of Balls per Innings = Ganguly
