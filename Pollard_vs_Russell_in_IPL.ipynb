# %% [markdown]
# <a href="https://colab.research.google.com/github/MahimnaDarji/Cricket-Analysis/blob/main/Pollard_vs_Russell_in_IPL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pollard Vs Russell in IPL

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/drive/MyDrive/DATASETS/cleaned_ipl_dataset_2008_to_2022.csv')

# %%
data.head(5)
# Out:
#    match_id  season  start_date                  venue  innings  ball  \
# 0    335982    2008  2008-04-18  M.Chinnaswamy Stadium        2   6.8
# 1    335982    2008  2008-04-18  M.Chinnaswamy Stadium        2   2.7
# 2    335982    2008  2008-04-18  M.Chinnaswamy Stadium        2   3.1
# 3    335982    2008  2008-04-18  M.Chinnaswamy Stadium        2   3.2
# 4    335982    2008  2008-04-18  M.Chinnaswamy Stadium        2   3.3
#
#                   batting_team           bowling_team     striker non_striker  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders  MV Boucher    CL White
# 1  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 2  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 3  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 4  Royal Challengers Bangalore  Kolkata Knight Riders   JH Kallis    W Jaffer
#
#    ... wides_cnt_balls  noballs_cnt_balls  noballs_cnt_balls_bowler  \
# ...

# %%
data.tail()
# Out:
#         match_id  season  start_date                             venue  \
# 225787   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225788   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225789   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225790   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225791   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
#
#         innings  ball      batting_team      bowling_team       striker  \
# 225787        1  13.6  Rajasthan Royals    Gujarat Titans    SO Hetmyer
# 225788        1  14.1  Rajasthan Royals    Gujarat Titans    SO Hetmyer
# 225789        1  14.2  Rajasthan Royals    Gujarat Titans      R Ashwin
# 225790        1  12.2  Rajasthan Royals    Gujarat Titans      R Ashwin
# 225791        2  18.1    Gujarat Titans  Rajasthan Royals  Shubman Gill
#
#        non_striker  ... wides_cnt_balls  noballs_cnt_balls  \
# ...

# %%
pol=data[data.striker == 'KA Pollard']
pol=pol[(pol.innings == 1) | (pol.innings == 2)]

# %%
pol.head(5)
# Out:
#        match_id  season  start_date             venue  innings  ball  \
# 29086    419114    2010  2010-03-17  Feroz Shah Kotla        1  18.6
# 29091    419114    2010  2010-03-17  Feroz Shah Kotla        1  19.4
# 29092    419114    2010  2010-03-17  Feroz Shah Kotla        1  19.5
# 29093    419114    2010  2010-03-17  Feroz Shah Kotla        1  19.6
# 29137    419114    2010  2010-03-17  Feroz Shah Kotla        1  18.3
#
#          batting_team      bowling_team     striker non_striker  ...  \
# 29086  Mumbai Indians  Delhi Daredevils  KA Pollard   SS Tiwary  ...
# 29091  Mumbai Indians  Delhi Daredevils  KA Pollard   R Sathish  ...
# 29092  Mumbai Indians  Delhi Daredevils  KA Pollard   R Sathish  ...
# 29093  Mumbai Indians  Delhi Daredevils  KA Pollard   R Sathish  ...
# 29137  Mumbai Indians  Delhi Daredevils  KA Pollard   SS Tiwary  ...
#
#       wides_cnt_balls  noballs_cnt_balls  noballs_cnt_balls_bowler  \
# ...

# %%
pol.tail()
# Out:
#         match_id  season  start_date                       venue  innings  \
# 221315   1304102    2022  2022-05-09  Dr DY Patil Sports Academy        2
# 221318   1304102    2022  2022-05-09  Dr DY Patil Sports Academy        2
# 221342   1304102    2022  2022-05-09  Dr DY Patil Sports Academy        2
# 221343   1304102    2022  2022-05-09  Dr DY Patil Sports Academy        2
# 221344   1304102    2022  2022-05-09  Dr DY Patil Sports Academy        2
#
#         ball    batting_team           bowling_team     striker   non_striker  \
# 221315  13.4  Mumbai Indians  Kolkata Knight Riders  KA Pollard  Ishan Kishan
# 221318  13.1  Mumbai Indians  Kolkata Knight Riders  KA Pollard  Ishan Kishan
# 221342  12.3  Mumbai Indians  Kolkata Knight Riders  KA Pollard  Ishan Kishan
# 221343  12.4  Mumbai Indians  Kolkata Knight Riders  KA Pollard  Ishan Kishan
# 221344  12.5  Mumbai Indians  Kolkata Knight Riders  KA Pollard  Ishan Kishan
#
# ...

# %%
russ=data[data.striker == 'AD Russell']
russ=russ[(russ.innings == 1) | (russ.innings == 2)]

# %%
russ.head(5)
# Out:
#        match_id  season  start_date             venue  innings  ball  \
# 73833    548372    2012  2012-05-17  Feroz Shah Kotla        2  15.5
# 73834    548372    2012  2012-05-17  Feroz Shah Kotla        2  15.6
# 73839    548372    2012  2012-05-17  Feroz Shah Kotla        2  19.3
# 73840    548372    2012  2012-05-17  Feroz Shah Kotla        2  19.2
# 73841    548372    2012  2012-05-17  Feroz Shah Kotla        2  19.1
#
#            batting_team                 bowling_team     striker  non_striker  \
# 73833  Delhi Daredevils  Royal Challengers Bangalore  AD Russell  LRPL Taylor
# 73834  Delhi Daredevils  Royal Challengers Bangalore  AD Russell  LRPL Taylor
# 73839  Delhi Daredevils  Royal Challengers Bangalore  AD Russell       P Negi
# 73840  Delhi Daredevils  Royal Challengers Bangalore  AD Russell       P Negi
# 73841  Delhi Daredevils  Royal Challengers Bangalore  AD Russell       P Negi
#
#        ... wides_cnt_balls  noballs_cnt_balls  noballs_cnt_balls_bowler  \
# ...

# %%
russ.tail(5)
# Out:
#         match_id  season  start_date                       venue  innings  \
# 223730   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
# 223732   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
# 223733   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
# 223734   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
# 223735   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
#
#         ball           batting_team          bowling_team     striker  \
# 223730  14.1  Kolkata Knight Riders  Lucknow Super Giants  AD Russell
# 223732  14.3  Kolkata Knight Riders  Lucknow Super Giants  AD Russell
# 223733  14.4  Kolkata Knight Riders  Lucknow Super Giants  AD Russell
# 223734  14.5  Kolkata Knight Riders  Lucknow Super Giants  AD Russell
# 223735  14.6  Kolkata Knight Riders  Lucknow Super Giants  AD Russell
#
#         non_striker  ... wides_cnt_balls  noballs_cnt_balls  \
# ...

# %% [markdown]
# #Pollard IPL Stats

# %%
print("Total Runs=",sum(pol['runs_off_bat']))
print("Balls Faced=",len(pol))
print("Strike Rate=",100*(sum(pol['runs_off_bat'])/len(pol)))
print("Times Dismissed=",sum(pol.player_dismissed == 'KA Pollard'))
print("Average=",(sum(pol['runs_off_bat'])/sum(pol.player_dismissed == 'KA Pollard')))
# Out:
# Total Runs= 3412
# Balls Faced= 2433
# Strike Rate= 140.23838882038635
# Times Dismissed= 118
# Average= 28.915254237288135

# %% [markdown]
# # Russell IPL Stats

# %%
print("Total Runs=",sum(russ['runs_off_bat']))
print("Total Ball Faced=",len(russ))
print("Strike Rate=",100*(sum(russ['runs_off_bat'])/len(russ)))
print("Times Dismissed=",sum(russ.player_dismissed == 'AD Russell'))
print("Average=",(sum(russ['runs_off_bat'])/sum(russ.player_dismissed == 'AD Russell')))
# Out:
# Total Runs= 2035
# Total Ball Faced= 1209
# Strike Rate= 168.3209263854425
# Times Dismissed= 64
# Average= 31.796875

# %% [markdown]
# #Dot Ball Percentage Of Both

# %%
pol1=data[data.striker == 'KA Pollard']
pol1=pol1[pol1.runs_off_bat == 0]
pol1=pol1[(pol1.innings == 1) | (pol1.innings == 2)]

# %%
pol1.head(5)
# Out:
#        match_id  season  start_date              venue  innings  ball  \
# 29086    419114    2010  2010-03-17   Feroz Shah Kotla        1  18.6
# 29092    419114    2010  2010-03-17   Feroz Shah Kotla        1  19.5
# 29093    419114    2010  2010-03-17   Feroz Shah Kotla        1  19.6
# 29175    419114    2010  2010-03-17   Feroz Shah Kotla        1  18.1
# 29973    419119    2010  2010-03-20  Brabourne Stadium        1  12.1
#
#          batting_team                 bowling_team     striker non_striker  \
# 29086  Mumbai Indians             Delhi Daredevils  KA Pollard   SS Tiwary
# 29092  Mumbai Indians             Delhi Daredevils  KA Pollard   R Sathish
# 29093  Mumbai Indians             Delhi Daredevils  KA Pollard   R Sathish
# 29175  Mumbai Indians             Delhi Daredevils  KA Pollard   SS Tiwary
# 29973  Mumbai Indians  Royal Challengers Bangalore  KA Pollard   R Sathish
#
#        ... wides_cnt_balls  noballs_cnt_balls  noballs_cnt_balls_bowler  \
# ...

# %%
pol1.tail(5)
# Out:
#         match_id  season  start_date                       venue  innings  \
# 221304   1304102    2022  2022-05-09  Dr DY Patil Sports Academy        2
# 221305   1304102    2022  2022-05-09  Dr DY Patil Sports Academy        2
# 221311   1304102    2022  2022-05-09  Dr DY Patil Sports Academy        2
# 221315   1304102    2022  2022-05-09  Dr DY Patil Sports Academy        2
# 221342   1304102    2022  2022-05-09  Dr DY Patil Sports Academy        2
#
#         ball    batting_team           bowling_team     striker   non_striker  \
# 221304  16.1  Mumbai Indians  Kolkata Knight Riders  KA Pollard   K Kartikeya
# 221305  16.2  Mumbai Indians  Kolkata Knight Riders  KA Pollard   K Kartikeya
# 221311  17.1  Mumbai Indians  Kolkata Knight Riders  KA Pollard     JJ Bumrah
# 221315  13.4  Mumbai Indians  Kolkata Knight Riders  KA Pollard  Ishan Kishan
# 221342  12.3  Mumbai Indians  Kolkata Knight Riders  KA Pollard  Ishan Kishan
#
# ...

# %%
russ1=data[data.striker == 'AD Russell']
russ1=russ1[russ1.runs_off_bat == 0]
russ1=russ1[(russ1.innings == 1)|(russ1.innings == 2)]

# %%
russ1.head(5)
# Out:
#        match_id  season  start_date                   venue  innings  ball  \
# 73839    548372    2012  2012-05-17        Feroz Shah Kotla        2  19.3
# 73840    548372    2012  2012-05-17        Feroz Shah Kotla        2  19.2
# 73844    548372    2012  2012-05-17        Feroz Shah Kotla        2  18.5
# 73855    548372    2012  2012-05-17        Feroz Shah Kotla        2  16.6
# 75977    548380    2012  2012-05-25  MA Chidambaram Stadium        2  10.5
#
#            batting_team                 bowling_team     striker  \
# 73839  Delhi Daredevils  Royal Challengers Bangalore  AD Russell
# 73840  Delhi Daredevils  Royal Challengers Bangalore  AD Russell
# 73844  Delhi Daredevils  Royal Challengers Bangalore  AD Russell
# 73855  Delhi Daredevils  Royal Challengers Bangalore  AD Russell
# 75977  Delhi Daredevils          Chennai Super Kings  AD Russell
#
#             non_striker  ... wides_cnt_balls  noballs_cnt_balls  \
# ...

# %%
russ1.tail(5)
# Out:
#         match_id  season  start_date                       venue  innings  \
# 223728   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
# 223732   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
# 223733   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
# 223734   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
# 223735   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
#
#         ball           batting_team          bowling_team     striker  \
# 223728  13.5  Kolkata Knight Riders  Lucknow Super Giants  AD Russell
# 223732  14.3  Kolkata Knight Riders  Lucknow Super Giants  AD Russell
# 223733  14.4  Kolkata Knight Riders  Lucknow Super Giants  AD Russell
# 223734  14.5  Kolkata Knight Riders  Lucknow Super Giants  AD Russell
# 223735  14.6  Kolkata Knight Riders  Lucknow Super Giants  AD Russell
#
#         non_striker  ... wides_cnt_balls  noballs_cnt_balls  \
# ...

# %%
print("Total Balls Faced By Pollard=",len(pol))
print("Dot Balls By Pollard=",len(pol1))
print("Dot Balls % =",100*(len(pol1)/len(pol)),"%")
# Out:
# Total Balls Faced By Pollard= 2433
# Dot Balls By Pollard= 962
# Dot Balls % = 39.5396629675298 %

# %%
print("Totals Balls Faced by Russell=",len(russ))
print("Dot Balls By Russell=",len(russ1))
print("Dot Balls %=",100*(len(russ1)/len(russ)),"%")
# Out:
# Totals Balls Faced by Russell= 1209
# Dot Balls By Russell= 507
# Dot Balls %= 41.935483870967744 %

# %% [markdown]
# ####Observation:- Russell Has Higher Dot Balls % then Pollard

# %% [markdown]
# #Boundary Percent of Both

# %%
russ2=data[data.striker == 'AD Russell']
russ2=russ2[(russ2.runs_off_bat == 4) | (russ2.runs_off_bat == 6)]
russ2=russ2[(russ2.innings == 1)|(russ2.innings == 2)]

# %%
russ2.head(5)
# Out:
#        match_id  season  start_date                   venue  innings  ball  \
# 73833    548372    2012  2012-05-17        Feroz Shah Kotla        2  15.5
# 73841    548372    2012  2012-05-17        Feroz Shah Kotla        2  19.1
# 73843    548372    2012  2012-05-17        Feroz Shah Kotla        2  18.6
# 73858    548372    2012  2012-05-17        Feroz Shah Kotla        2  16.3
# 75964    548380    2012  2012-05-25  MA Chidambaram Stadium        2   8.4
#
#            batting_team                 bowling_team     striker  \
# 73833  Delhi Daredevils  Royal Challengers Bangalore  AD Russell
# 73841  Delhi Daredevils  Royal Challengers Bangalore  AD Russell
# 73843  Delhi Daredevils  Royal Challengers Bangalore  AD Russell
# 73858  Delhi Daredevils  Royal Challengers Bangalore  AD Russell
# 75964  Delhi Daredevils          Chennai Super Kings  AD Russell
#
#             non_striker  ... wides_cnt_balls  noballs_cnt_balls  \
# ...

# %%
russ2.tail(5)
# Out:
#         match_id  season  start_date                                    venue  \
# 222491   1304107    2022  2022-05-14  Maharashtra Cricket Association Stadium
# 222560   1304107    2022  2022-05-14  Maharashtra Cricket Association Stadium
# 222566   1304107    2022  2022-05-14  Maharashtra Cricket Association Stadium
# 222584   1304107    2022  2022-05-14  Maharashtra Cricket Association Stadium
# 222613   1304107    2022  2022-05-14  Maharashtra Cricket Association Stadium
#
#         innings  ball           batting_team         bowling_team     striker  \
# 222491        1  19.3  Kolkata Knight Riders  Sunrisers Hyderabad  AD Russell
# 222560        1  16.1  Kolkata Knight Riders  Sunrisers Hyderabad  AD Russell
# 222566        1  16.7  Kolkata Knight Riders  Sunrisers Hyderabad  AD Russell
# 222584        1  14.6  Kolkata Knight Riders  Sunrisers Hyderabad  AD Russell
# 222613        1  13.1  Kolkata Knight Riders  Sunrisers Hyderabad  AD Russell
#
# ...

# %%
pol2=data[data.striker == 'KA Pollard']
pol2=pol2[(pol2.runs_off_bat == 4) | (pol2.runs_off_bat == 6)]
pol2=pol2[(pol2.innings == 1)|(pol2.innings == 2)]

# %%
pol2.head(5)
# Out:
#        match_id  season  start_date              venue  innings  ball  \
# 29091    419114    2010  2010-03-17   Feroz Shah Kotla        1  19.4
# 29169    419114    2010  2010-03-17   Feroz Shah Kotla        1  18.2
# 30011    419119    2010  2010-03-20  Brabourne Stadium        1  16.5
# 30015    419119    2010  2010-03-20  Brabourne Stadium        1  16.1
# 31014    419122    2010  2010-03-22  Brabourne Stadium        2  15.4
#
#          batting_team                 bowling_team     striker   non_striker  \
# 29091  Mumbai Indians             Delhi Daredevils  KA Pollard     R Sathish
# 29169  Mumbai Indians             Delhi Daredevils  KA Pollard     SS Tiwary
# 30011  Mumbai Indians  Royal Challengers Bangalore  KA Pollard     R Sathish
# 30015  Mumbai Indians  Royal Challengers Bangalore  KA Pollard     R Sathish
# 31014  Mumbai Indians        Kolkata Knight Riders  KA Pollard  SR Tendulkar
#
#        ... wides_cnt_balls  noballs_cnt_balls  noballs_cnt_balls_bowler  \
# ...

# %%
pol2.tail(5)
# Out:
#         match_id  season  start_date                       venue  innings  \
# 214389   1304072    2022  2022-04-16           Brabourne Stadium        2
# 215889   1304079    2022  2022-04-21  Dr DY Patil Sports Academy        1
# 215895   1304079    2022  2022-04-21  Dr DY Patil Sports Academy        1
# 216625   1304083    2022  2022-04-24            Wankhede Stadium        2
# 221343   1304102    2022  2022-05-09  Dr DY Patil Sports Academy        2
#
#         ball    batting_team           bowling_team     striker   non_striker  \
# 214389  16.2  Mumbai Indians   Lucknow Super Giants  KA Pollard      FA Allen
# 215889  14.4  Mumbai Indians    Chennai Super Kings  KA Pollard   Tilak Varma
# 215895  13.4  Mumbai Indians    Chennai Super Kings  KA Pollard   Tilak Varma
# 216625  16.2  Mumbai Indians   Lucknow Super Giants  KA Pollard   Tilak Varma
# 221343  12.4  Mumbai Indians  Kolkata Knight Riders  KA Pollard  Ishan Kishan
#
# ...

# %%
print("Total Balls Faced by Pollard=",len(pol))
print("Boundary Balls=",len(pol2))
print("Boundary Balls %=",100*(len(pol2)/len(pol)),"%")
# Out:
# Total Balls Faced by Pollard= 2433
# Boundary Balls= 441
# Boundary Balls %= 18.12577065351418 %

# %%
print("Total Balls Faced by Russell=",len(russ))
print("Boundary Balls=",len(russ2))
print("Boundary Balls %=",100*(len(russ2)/len(russ)),"%")
# Out:
# Total Balls Faced by Russell= 1209
# Boundary Balls= 312
# Boundary Balls %= 25.806451612903224 %

# %% [markdown]
# ####Observation:- Russell Has Higher Boundary Balls % then Pollard

# %%
print("Total Runs Of Pollard=",sum(pol['runs_off_bat']))
print("Runs Through Boundaries=",sum(pol2['runs_off_bat']))
print("Boundary%=",100*(sum(pol2['runs_off_bat'])/sum(pol['runs_off_bat'])),"%")
# Out:
# Total Runs Of Pollard= 3412
# Runs Through Boundaries= 2210
# Boundary%= 64.77139507620164 %

# %%
print("Total Runs Of Russell=",sum(russ['runs_off_bat']))
print("Runs Through Boundaries=",sum(russ2['runs_off_bat']))
print("Boundary%=",100*(sum(russ2['runs_off_bat'])/sum(russ['runs_off_bat'])),"%")
# Out:
# Total Runs Of Russell= 2035
# Runs Through Boundaries= 1598
# Boundary%= 78.52579852579854 %

# %% [markdown]
# ####Observation:- Russell scores around 79% of his runs from boundaries while Pollard scores 65% from boundaries

# %% [markdown]
# #Percentage Of Team's Runs Scored During their Playing Time

# %%
mi=data[data.batting_team == 'Mumbai Indians']
mi=mi[(mi.innings == 1) | (mi.innings == 2)]
mi=mi[(mi.season >= 2010) & (mi.season <= 2022)]

# %%
mi.tail(5)
# Out:
#         match_id  season  start_date             venue  innings  ball  \
# 224465   1304115    2022  2022-05-21  Wankhede Stadium        2  13.6
# 224466   1304115    2022  2022-05-21  Wankhede Stadium        2  14.1
# 224467   1304115    2022  2022-05-21  Wankhede Stadium        2  14.2
# 224468   1304115    2022  2022-05-21  Wankhede Stadium        2  14.5
# 224470   1304115    2022  2022-05-21  Wankhede Stadium        2  17.3
#
#           batting_team    bowling_team   striker  non_striker  ...  \
# 224465  Mumbai Indians  Delhi Capitals  D Brevis  Tilak Varma  ...
# 224466  Mumbai Indians  Delhi Capitals  D Brevis  Tilak Varma  ...
# 224467  Mumbai Indians  Delhi Capitals  D Brevis  Tilak Varma  ...
# 224468  Mumbai Indians  Delhi Capitals  TH David  Tilak Varma  ...
# 224470  Mumbai Indians  Delhi Capitals  TH David  Tilak Varma  ...
#
#        wides_cnt_balls  noballs_cnt_balls  noballs_cnt_balls_bowler  \
# 224465               1                  1                         1
# ...

# %%
kkr=data[data.batting_team == 'Kolkata Knight Riders']
kkr=kkr[(kkr.innings == 1) | (kkr.innings == 2)]
kkr=kkr[(kkr.season >= 2014) & (kkr.season <= 2022)]

# %%
kkr.head(5)
# Out:
#        match_id  season  start_date                 venue  innings  ball  \
# 94625    729279    2014  2014-04-16  Sheikh Zayed Stadium        1  19.1
# 94626    729279    2014  2014-04-16  Sheikh Zayed Stadium        1  19.5
# 94627    729279    2014  2014-04-16  Sheikh Zayed Stadium        1   4.7
# 94628    729279    2014  2014-04-16  Sheikh Zayed Stadium        1   4.8
# 94629    729279    2014  2014-04-16  Sheikh Zayed Stadium        1   5.1
#
#                 batting_team    bowling_team    striker non_striker  ...  \
# 94625  Kolkata Knight Riders  Mumbai Indians   SA Yadav   YK Pathan  ...
# 94626  Kolkata Knight Riders  Mumbai Indians   SA Yadav   YK Pathan  ...
# 94627  Kolkata Knight Riders  Mumbai Indians  MK Pandey   JH Kallis  ...
# 94628  Kolkata Knight Riders  Mumbai Indians  MK Pandey   JH Kallis  ...
# 94629  Kolkata Knight Riders  Mumbai Indians  MK Pandey   JH Kallis  ...
#
#       wides_cnt_balls  noballs_cnt_balls  noballs_cnt_balls_bowler  \
# ...

# %%
print("Total Runs Scored by Mumbai Indians After Pollard's Debut=",sum(mi['runs_off_bat']))
print("Runs Scored by Pollard=",sum(pol['runs_off_bat']))
print("Scored Percentage of Team's Runs=",100*(sum(pol['runs_off_bat'])/sum(mi['runs_off_bat'])),"%")
# Out:
# Total Runs Scored by Mumbai Indians After Pollard's Debut= 30999
# Runs Scored by Pollard= 3412
# Scored Percentage of Team's Runs= 11.006806671182941 %

# %%
print("Total Runs Scored by KKR After Russell's Debut=",sum(kkr['runs_off_bat']))
print("Runs Scored by Russell=",sum(russ['runs_off_bat']))
print("Scored Percentage of Team's Runs=",100*(sum(russ['runs_off_bat'])/sum(kkr['runs_off_bat'])),"%")
# Out:
# Total Runs Scored by KKR After Russell's Debut= 20460
# Runs Scored by Russell= 2035
# Scored Percentage of Team's Runs= 9.946236559139784 %

# %% [markdown]
# ####Observation:- Pollard has contributed more towards teams runs then Russell

# %% [markdown]
# ###Top Batters of MI during Pollard's Career

# %%
mi.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False).head(10)
# Out:
# striker
# RG Sharma       4709
# KA Pollard      3412
# AT Rayudu       2416
# SA Yadav        2036
# SR Tendulkar    1781
# Ishan Kishan    1551
# HH Pandya       1476
# Q de Kock       1329
# KH Pandya       1143
# LMP Simmons     1079
# Name: runs_off_bat, dtype: int64

# %%
plt.figure(figsize=(12,6))
mi.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.xlabel('Player Name')
plt.ylabel('Total Runs')
plt.show()

# %%
mi.groupby('striker')['ball'].count().sort_values(ascending=False).head(10)
# Out:
# striker
# RG Sharma       3720
# KA Pollard      2433
# AT Rayudu       1964
# SR Tendulkar    1539
# SA Yadav        1498
# Ishan Kishan    1189
# Q de Kock       1030
# HH Pandya       1013
# LMP Simmons      878
# KH Pandya        853
# Name: ball, dtype: int64

# %%
plt.figure(figsize=(12,6))
mi.groupby('striker')['ball'].count().sort_values(ascending=False).head(10).plot(kind='bar')
plt.xlabel('Player Name')
plt.ylabel('Total Balls Faced')
plt.show()

# %% [markdown]
# ###Top Batters of KKR during Russell's Career

# %%
kkr.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False).head(10)
# Out:
# striker
# RV Uthappa      2439
# AD Russell      1977
# N Rana          1744
# G Gambhir       1661
# Shubman Gill    1417
# CA Lynn         1274
# MK Pandey       1270
# KD Karthik      1143
# YK Pathan       1084
# SP Narine        995
# Name: runs_off_bat, dtype: int64

# %%
plt.figure(figsize=(12,6))
kkr.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.xlabel('Player Name')
plt.ylabel('Total Runs')
plt.show()

# %%
kkr.groupby('striker')['ball'].count().sort_values(ascending=False).head(10)
# Out:
# striker
# RV Uthappa      1839
# G Gambhir       1418
# N Rana          1322
# Shubman Gill    1181
# AD Russell      1167
# MK Pandey       1048
# CA Lynn          928
# KD Karthik       835
# YK Pathan        790
# SP Narine        636
# Name: ball, dtype: int64

# %%
plt.figure(figsize=(12,6))
kkr.groupby('striker')['ball'].count().sort_values(ascending=False).head(10).plot(kind='bar')
plt.xlabel('Player Name')
plt.ylabel('Total Runs')
plt.show()

# %% [markdown]
# ###Percent of Runs through Boundaries

# %%
mi1=data[data.batting_team == 'Mumbai Indians']
mi1=mi1[(mi1.runs_off_bat == 4 ) | (mi1.runs_off_bat == 6 )]
mi1=mi1[(mi1.innings == 1) | (mi1.innings == 2)]
mi1=mi1[(mi1.season >= 2010) & (mi1.season <= 2022)]

# %%
mi1.tail(5)
# Out:
#         match_id  season  start_date             venue  innings  ball  \
# 224437   1304115    2022  2022-05-21  Wankhede Stadium        2  14.7
# 224441   1304115    2022  2022-05-21  Wankhede Stadium        2   9.6
# 224443   1304115    2022  2022-05-21  Wankhede Stadium        2  10.2
# 224454   1304115    2022  2022-05-21  Wankhede Stadium        2  12.1
# 224470   1304115    2022  2022-05-21  Wankhede Stadium        2  17.3
#
#           batting_team    bowling_team       striker  non_striker  ...  \
# 224437  Mumbai Indians  Delhi Capitals      TH David  Tilak Varma  ...
# 224441  Mumbai Indians  Delhi Capitals  Ishan Kishan     D Brevis  ...
# 224443  Mumbai Indians  Delhi Capitals  Ishan Kishan     D Brevis  ...
# 224454  Mumbai Indians  Delhi Capitals      D Brevis  Tilak Varma  ...
# 224470  Mumbai Indians  Delhi Capitals      TH David  Tilak Varma  ...
#
#        wides_cnt_balls  noballs_cnt_balls  noballs_cnt_balls_bowler  \
# ...

# %%
kkr1=data[data.batting_team == 'Kolkata Knight Riders']
kkr1=kkr1[(kkr1.runs_off_bat == 4 ) | (kkr1.runs_off_bat == 6 )]
kkr1=kkr1[(kkr1.innings == 1) | (kkr1.innings == 2)]
kkr1=kkr1[(kkr1.season >= 2014) & (kkr1.season <= 2022)]

# %%
kkr1.tail(5)
# Out:
#         match_id  season  start_date                       venue  innings  \
# 223703   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
# 223706   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
# 223708   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
# 223710   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
# 223715   1304112    2022  2022-05-18  Dr DY Patil Sports Academy        2
#
#         ball           batting_team          bowling_team      striker  \
# 223703   0.5  Kolkata Knight Riders  Lucknow Super Giants       N Rana
# 223706  15.3  Kolkata Knight Riders  Lucknow Super Giants  SW Billings
# 223708  10.4  Kolkata Knight Riders  Lucknow Super Giants  SW Billings
# 223710  10.6  Kolkata Knight Riders  Lucknow Super Giants      SS Iyer
# 223715  11.5  Kolkata Knight Riders  Lucknow Super Giants      SS Iyer
#
#         non_striker  ... wides_cnt_balls  noballs_cnt_balls  \
# ...

# %%
print("Total Boundary Runs By MI during Pollard's Time=",sum(mi1['runs_off_bat']))
print("Pollard's Runs Through Boundaries=",sum(pol2['runs_off_bat']))
print("Contribution to Teams Runs=",100*(sum(pol2['runs_off_bat'])/sum(mi1['runs_off_bat'])),"%")
# Out:
# Total Boundary Runs By MI during Pollard's Time= 18928
# Pollard's Runs Through Boundaries= 2210
# Contribution to Teams Runs= 11.675824175824175 %

# %%
print("Total Boundary Runs By KKR during Russell's Time=",sum(kkr1['runs_off_bat']))
print("Russell's Runs Through Boundaries=",sum(russ2['runs_off_bat']))
print("Contribution to Teams Runs=",100*(sum(russ2['runs_off_bat'])/sum(kkr1['runs_off_bat'])),"%")
# Out:
# Total Boundary Runs By KKR during Russell's Time= 12744
# Russell's Runs Through Boundaries= 1598
# Contribution to Teams Runs= 12.539234149403642 %

# %% [markdown]
# ####Observation:- Pollard contributed around 11.7% in Teams runs through boundaries while Russell contributed 12.5%

# %% [markdown]
# ###MI Batters who scored most runs through Boundaries

# %%
mi1.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False).head(10)
# Out:
# striker
# RG Sharma       2832
# KA Pollard      2210
# SA Yadav        1298
# AT Rayudu       1294
# SR Tendulkar    1026
# HH Pandya        976
# Ishan Kishan     960
# Q de Kock        804
# LMP Simmons      700
# KH Pandya        696
# Name: runs_off_bat, dtype: int64

# %%
plt.figure(figsize=(12,6))
mi1.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False).head(10).plot(kind='barh')
plt.xlabel('Total Runs')
plt.ylabel('Player Name')
plt.show()

# %% [markdown]
# ###KKR Batters who scored most runs through Boundaries

# %%
kkr1.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False).head(10)
# Out:
# striker
# AD Russell      1568
# RV Uthappa      1530
# N Rana          1152
# G Gambhir        898
# CA Lynn          886
# SP Narine        806
# Shubman Gill     764
# KD Karthik       698
# YK Pathan        650
# MK Pandey        636
# Name: runs_off_bat, dtype: int64

# %%
plt.figure(figsize=(12,6))
kkr1.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False).head(10).plot(kind='barh')
plt.xlabel('Total Runs')
plt.ylabel('Player Name')
plt.show()
