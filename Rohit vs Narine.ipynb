# %% [markdown]
# # Rohit V/S Narine

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('https://raw.githubusercontent.com/madaboutsports-mas/MAS-ACA-Masterclass/main/CSV%20Files/IPL_ball_by_ball_updated.csv?token=GHSAT0AAAAAAB6PBHSOZFPPOE6B2YAERR74ZAHGBSA')

# %%
data.head()
# Out:
#    match_id  season  start_date                  venue  innings  ball  \
# 0    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   6.8
# 1    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   2.7
# 2    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.1
# 3    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.2
# 4    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.3
#
#                   batting_team           bowling_team     striker non_striker  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders  MV Boucher    CL White
# 1  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 2  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 3  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 4  Royal Challengers Bangalore  Kolkata Knight Riders   JH Kallis    W Jaffer
#
#    ... extras  wides  noballs  byes  legbyes  penalty  wicket_type  \
# ...

# %%
data.tail(5)
# Out:
#         match_id  season  start_date                             venue  \
# 225948   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225949   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225950   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225951   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225952   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
#
#         innings  ball      batting_team      bowling_team       striker  \
# 225948        1  13.6  Rajasthan Royals    Gujarat Titans    SO Hetmyer
# 225949        1  14.1  Rajasthan Royals    Gujarat Titans    SO Hetmyer
# 225950        1  14.2  Rajasthan Royals    Gujarat Titans      R Ashwin
# 225951        1  12.2  Rajasthan Royals    Gujarat Titans      R Ashwin
# 225952        2  18.1    Gujarat Titans  Rajasthan Royals  Shubman Gill
#
#        non_striker  ... extras  wides  noballs  byes  legbyes  penalty  \
# ...

# %%
data.innings.unique()
# Out:
# array([2, 1, 4, 3, 6, 5], dtype=int64)

# %%
data=data[(data.innings == 1) | (data.innings == 2)]

# %%
data.innings.unique()
# Out:
# array([2, 1], dtype=int64)

# %%
data.dtypes
# Out:
# match_id                    int64
# season                      int64
# start_date                 object
# venue                      object
# innings                     int64
# ball                      float64
# batting_team               object
# bowling_team               object
# striker                    object
# non_striker                object
# bowler                     object
# runs_off_bat                int64
# extras                      int64
# wides                     float64
# noballs                   float64
# byes                      float64
# legbyes                   float64
# penalty                   float64
# wicket_type                object
# player_dismissed           object
# other_wicket_type         float64
# other_player_dismissed    float64
# dtype: object

# %%
rvs=data[(data.striker == 'RG Sharma') & (data.bowler == 'SP Narine')]

# %%
rvs.head(50)
# Out:
#         match_id  season  start_date                 venue  innings  ball  \
# 72015     548363    2012  2012-05-12          Eden Gardens        1   5.5
# 72073     548363    2012  2012-05-12          Eden Gardens        1  15.1
# 72075     548363    2012  2012-05-12          Eden Gardens        1  15.3
# 72076     548363    2012  2012-05-12          Eden Gardens        1  15.4
# 72077     548363    2012  2012-05-12          Eden Gardens        1  15.5
# 72087     548363    2012  2012-05-12          Eden Gardens        1  17.2
# 72089     548363    2012  2012-05-12          Eden Gardens        1  17.4
# 73542     548370    2012  2012-05-16      Wankhede Stadium        2  17.5
# 84134     598029    2013  2013-04-24          Eden Gardens        2  16.5
# 84140     598029    2013  2013-04-24          Eden Gardens        2  10.5
# 84144     598029    2013  2013-04-24          Eden Gardens        2  10.1
# 84162     598029    2013  2013-04-24          Eden Gardens        2  16.6
# ...

# %%
#Runs Scored by Rohit Of Narine
print("Total Runs Scored=",sum((rvs.runs_off_bat)))
# Out:
# Total Runs Scored= 137

# %%
#No. Of Times Dismissed Vs Narine
len(rvs[rvs.player_dismissed == 'RG Sharma'])
# Out:
# 7

# %%
#No Of Balls Faced 
print("Number Of Balls Faced",len(rvs))
# Out:
# Number Of Balls Faced 128

# %%
# Strike Of Rate Of Rohit vs Narine
print("Strike Rate of Rohit=",100*sum((rvs.runs_off_bat))/len(rvs))
# Out:
# Strike Rate of Rohit= 107.03125

# %%
#Average Of Rohit vs Narine
print("Average is=",sum((rvs.runs_off_bat))/len(rvs[rvs.player_dismissed == 'RG Sharma']))
# Out:
# Average is= 19.571428571428573

# %%
#Modes Of Dismissals vs Narine
rvs[rvs.player_dismissed == 'RG Sharma']
# Out:
#         match_id  season  start_date                             venue  \
# 73542     548370    2012  2012-05-16                  Wankhede Stadium
# 84162     598029    2013  2013-04-24                      Eden Gardens
# 103664    734009    2014  2014-05-14                  Barabati Stadium
# 120559    829805    2015  2015-05-14                  Wankhede Stadium
# 138013   1082597    2017  2017-04-09                  Wankhede Stadium
# 159251   1136597    2018  2018-05-06                  Wankhede Stadium
# 201608   1254096    2021  2021-09-23  Zayed Cricket Stadium, Abu Dhabi
#
#         innings  ball    batting_team           bowling_team    striker  \
# 73542         2  17.5  Mumbai Indians  Kolkata Knight Riders  RG Sharma
# 84162         2  16.6  Mumbai Indians  Kolkata Knight Riders  RG Sharma
# 103664        1  19.2  Mumbai Indians  Kolkata Knight Riders  RG Sharma
# 120559        1  11.4  Mumbai Indians  Kolkata Knight Riders  RG Sharma
# ...

# %% [markdown]
# ### Rohit is Mostly Dismissed by Narine through Catch Out

# %%
narine=data[data.bowler == 'SP Narine']

# %%
narine.tail(5)
# Out:
#         match_id  season  start_date                               venue  \
# 224013   1304112    2022  2022-05-18  Dr DY Patil Sports Academy, Mumbai
# 224014   1304112    2022  2022-05-18  Dr DY Patil Sports Academy, Mumbai
# 224015   1304112    2022  2022-05-18  Dr DY Patil Sports Academy, Mumbai
# 224016   1304112    2022  2022-05-18  Dr DY Patil Sports Academy, Mumbai
# 224020   1304112    2022  2022-05-18  Dr DY Patil Sports Academy, Mumbai
#
#         innings  ball          batting_team           bowling_team    striker  \
# 224013        1  14.5  Lucknow Super Giants  Kolkata Knight Riders   KL Rahul
# 224014        1  14.4  Lucknow Super Giants  Kolkata Knight Riders  Q de Kock
# 224015        1  14.3  Lucknow Super Giants  Kolkata Knight Riders   KL Rahul
# 224016        1  14.2  Lucknow Super Giants  Kolkata Knight Riders  Q de Kock
# 224020        1  14.1  Lucknow Super Giants  Kolkata Knight Riders  Q de Kock
#
# ...

# %%
rohit=data[data.striker == 'RG Sharma']

# %%
rohit.head(5)
# Out:
#       match_id  season  start_date                                      venue  \
# 784     335986    2008  2008-04-20                               Eden Gardens
# 785     335986    2008  2008-04-20                               Eden Gardens
# 786     335986    2008  2008-04-20                               Eden Gardens
# 1445    335988    2008  2008-04-22  Rajiv Gandhi International Stadium, Uppal
# 1447    335988    2008  2008-04-22  Rajiv Gandhi International Stadium, Uppal
#
#       innings  ball     batting_team           bowling_team    striker  \
# 784         1   8.4  Deccan Chargers  Kolkata Knight Riders  RG Sharma
# 785         1   8.3  Deccan Chargers  Kolkata Knight Riders  RG Sharma
# 786         1   8.2  Deccan Chargers  Kolkata Knight Riders  RG Sharma
# 1445        1  17.4  Deccan Chargers       Delhi Daredevils  RG Sharma
# 1447        1  17.2  Deccan Chargers       Delhi Daredevils  RG Sharma
#
# ...

# %%
#Most Runs Scored vs Narine (Top 10 Batsmen)
n1=narine.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False).head(10)
n1
# Out:
# striker
# DA Warner      176
# RG Sharma      137
# SK Raina       118
# KL Rahul       105
# V Kohli        101
# S Dhawan        85
# WP Saha         72
# AM Rahane       71
# RA Tripathi     71
# CH Gayle        65
# Name: runs_off_bat, dtype: int64

# %%
n1=narine.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.xlabel('Player Name')
plt.ylabel('Total Runs')
plt.show()

# %%
#Most Ball Faced vs Narine
n2=narine.groupby('striker')['ball'].count().sort_values(ascending=False).head(10)
n2
# Out:
# striker
# RG Sharma    128
# DA Warner    115
# V Kohli       98
# SK Raina      88
# SV Samson     78
# S Dhawan      77
# MS Dhoni      74
# KL Rahul      70
# CH Gayle      69
# WP Saha       61
# Name: ball, dtype: int64

# %%
n2=narine.groupby('striker')['ball'].count().sort_values(ascending=False).head(10).plot(kind='bar')
plt.xlabel('Player Name')
plt.ylabel('Total Balls Faced')
plt.show()

# %%
n3=narine.groupby('striker')['player_dismissed'].count().sort_values(ascending=False).head(10)
n3
# Out:
# striker
# RG Sharma         8
# SR Watson         5
# AB de Villiers    4
# AM Rahane         4
# MEK Hussey        4
# BB McCullum       3
# Lalit Yadav       3
# GJ Maxwell        3
# S Nadeem          3
# AT Rayudu         3
# Name: player_dismissed, dtype: int64

# %%
n3=narine.groupby('striker')['player_dismissed'].count().sort_values(ascending=False).head(10).plot(kind='bar')
plt.xlabel('Player Name')
plt.ylabel('Times Dismissed')
plt.show()

# %%
n1=pd.DataFrame(narine.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False)).reset_index()

# %%
n2=pd.DataFrame(narine.groupby('striker')['ball'].count().sort_values(ascending=False)).reset_index()

# %%
n3=pd.DataFrame(narine.groupby('striker')['player_dismissed'].count().sort_values(ascending=False)).reset_index()

# %%
n4=n1.merge(n2,on='striker',how='left')
n4
# Out:
#            striker  runs_off_bat  ball
# 0        DA Warner           176   115
# 1        RG Sharma           137   128
# 2         SK Raina           118    88
# 3         KL Rahul           105    70
# 4          V Kohli           101    98
# ..             ...           ...   ...
# 210       TA Boult             0     1
# 211        P Dogra             0     1
# 212        P Kumar             0     1
# 213      R Rampaul             0     1
# 214  KC Sangakkara             0     3
#
# [215 rows x 3 columns]

# %%
n5=n3.merge(n4,on='striker',how='left')
n5.head(10)
# Out:
#           striker  player_dismissed  runs_off_bat  ball
# 0       RG Sharma                 8           137   128
# 1       SR Watson                 5            33    33
# 2  AB de Villiers                 4            53    40
# 3       AM Rahane                 4            71    58
# 4      MEK Hussey                 4            37    44
# 5     BB McCullum                 3            32    30
# 6     Lalit Yadav                 3             4    15
# 7      GJ Maxwell                 3            58    57
# 8        S Nadeem                 3             6    12
# 9       AT Rayudu                 3            51    60

# %%
n5['StrikeRate']=100*n5['runs_off_bat']/n5['ball']
n5=n5[(n5.ball >= 40) & (n5.player_dismissed >= 2)]
n5['Average']=n5['runs_off_bat']/n5['player_dismissed']
n5['StrPAvg']=n5['StrikeRate']+ n5['Average']
n5
# Out:
#            striker  player_dismissed  runs_off_bat  ball  StrikeRate  \
# 0        RG Sharma                 8           137   128  107.031250
# 2   AB de Villiers                 4            53    40  132.500000
# 3        AM Rahane                 4            71    58  122.413793
# 4       MEK Hussey                 4            37    44   84.090909
# 7       GJ Maxwell                 3            58    57  101.754386
# 9        AT Rayudu                 3            51    60   85.000000
# 11        SK Raina                 3           118    88  134.090909
# 12       RA Jadeja                 3            48    49   97.959184
# 14       SV Samson                 3            64    78   82.051282
# 15         V Kohli                 3           101    98  103.061224
# 16         WP Saha                 3            72    61  118.032787
# 17   Mandeep Singh                 3            58    43  134.883721
# 22         NV Ojha                 2            32    52   61.538462
# ...

# %%
n5.shape
# Out:
# (20, 7)

# %%
#Rohit vs Other Bowlers
r1=rohit.groupby('bowler')['runs_off_bat'].sum().sort_values(ascending=False).head(10)
r1
# Out:
# bowler
# PP Chawla          146
# UT Yadav           144
# SP Narine          137
# M Morkel           119
# R Ashwin           105
# R Bhatia           100
# AD Russell          97
# Shakib Al Hasan     92
# A Mishra            87
# JH Kallis           82
# Name: runs_off_bat, dtype: int64

# %%
r1=rohit.groupby('bowler')['runs_off_bat'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.xlabel('Player Name')
plt.ylabel('Total Runs')
plt.show()

# %%
#Bowlers Rohit has faced most
r2=rohit.groupby('bowler')['ball'].count().sort_values(ascending=False).head(10)
r2
# Out:
# bowler
# SP Narine          128
# R Ashwin           118
# PP Chawla          115
# UT Yadav           104
# A Mishra            91
# DJ Bravo            75
# RA Jadeja           74
# Shakib Al Hasan     72
# M Morkel            69
# R Bhatia            63
# Name: ball, dtype: int64

# %%
r2=rohit.groupby('bowler')['ball'].count().sort_values(ascending=False).head(10).plot(kind='barh')
plt.ylabel('Player Name')
plt.xlabel('Total Balls')
plt.show()

# %%
r3=rohit.groupby('bowler')['player_dismissed'].count().sort_values(ascending=False).head(10)
r3
# Out:
# bowler
# SP Narine         8
# A Mishra          7
# R Vinay Kumar     6
# SK Trivedi        6
# DJ Bravo          5
# UT Yadav          5
# SK Warne          4
# R Ashwin          4
# Sandeep Sharma    4
# DS Kulkarni       4
# Name: player_dismissed, dtype: int64

# %%
r3=rohit.groupby('bowler')['player_dismissed'].count().sort_values(ascending=False).head(10).plot(kind='bar')
plt.ylabel('Player Name')
plt.xlabel('Total Balls')
plt.show()

# %%
r1=pd.DataFrame(rohit.groupby('bowler')['runs_off_bat'].sum().sort_values(ascending=False)).reset_index()

# %%
r2=pd.DataFrame(rohit.groupby('bowler')['ball'].count().sort_values(ascending=False)).reset_index()

# %%
r3=pd.DataFrame(rohit.groupby('bowler')['player_dismissed'].count().sort_values(ascending=False)).reset_index()

# %%
r4=r1.merge(r2,on='bowler',how='left')
r4
# Out:
#            bowler  runs_off_bat  ball
# 0       PP Chawla           146   115
# 1        UT Yadav           144   104
# 2       SP Narine           137   128
# 3        M Morkel           119    69
# 4        R Ashwin           105   118
# ..            ...           ...   ...
# 248  CRD Fernando             0     1
# 249  BE Hendricks             0     1
# 250        MM Ali             0     1
# 251    A Chandila             0     1
# 252     DJ Willey             0     3
#
# [253 rows x 3 columns]

# %%
r5=r4.merge(r3,on='bowler',how='left')
r5['StrikeRate']=100*r5['runs_off_bat']/r5['ball']
r5=r5[(r5.player_dismissed >= 3) & (r5.ball >= 40)]
r5['Average']=r5['runs_off_bat']/r5['player_dismissed']
r5['StrPAvg']=r5['StrikeRate'] + r5['Average']
r5
# Out:
#             bowler  runs_off_bat  ball  player_dismissed  StrikeRate  \
# 1         UT Yadav           144   104                 5  138.461538
# 2        SP Narine           137   128                 8  107.031250
# 4         R Ashwin           105   118                 4   88.983051
# 8         A Mishra            87    91                 7   95.604396
# 10        DJ Bravo            82    75                 5  109.333333
# 15       RA Jadeja            71    74                 3   95.945946
# 19     DS Kulkarni            65    42                 4  154.761905
# 27  Mohammed Shami            56    48                 3  116.666667
# 28        SK Warne            52    52                 4  100.000000
# 35        I Sharma            48    40                 3  120.000000
# 50  Sandeep Sharma            37    42                 4   88.095238
#
#       Average     StrPAvg
# 1   28.800000  167.261538
# 2   17.125000  124.156250
# 4   26.250000  115.233051
# 8   12.428571  108.032967
# ...

# %%
plt.figure(figsize=(16,8))
size=[r5.player_dismissed * 50]
plt.scatter(r5.Average,r5.StrikeRate,s=size,alpha=1)
plt.title('Rohit StrPAvg Vs Bowlers he struggles most')
plt.axvline(16,ls='--',color='red')
plt.axhline(100,ls='--',color='red')
plt.show()
