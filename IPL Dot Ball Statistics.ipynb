# %% [markdown]
# ## IPL Dot Balls Statistics

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('https://raw.githubusercontent.com/madaboutsports-mas/MAS-ACA-Masterclass/main/CSV%20Files/IPL_ball_by_ball_updated.csv?token=GHSAT0AAAAAAB6PBHSPL6HY4Q3BA7POGSNCZAUIU6Q')

# %%
data.tail()
# Out:
#         match_id  season  start_date                             venue  \
# 225948   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225949   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225950   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225951   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225952   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
#
#         innings  ball      batting_team      bowling_team       striker  \
# 225948        1  13.6  Rajasthan Royals    Gujarat Titans    SO Hetmyer
# 225949        1  14.1  Rajasthan Royals    Gujarat Titans    SO Hetmyer
# 225950        1  14.2  Rajasthan Royals    Gujarat Titans      R Ashwin
# 225951        1  12.2  Rajasthan Royals    Gujarat Titans      R Ashwin
# 225952        2  18.1    Gujarat Titans  Rajasthan Royals  Shubman Gill
#
#        non_striker  ... extras  wides  noballs  byes  legbyes  penalty  \
# ...

# %%
data.dtypes
# Out:
# match_id                    int64
# season                      int64
# start_date                 object
# venue                      object
# innings                     int64
# ball                      float64
# batting_team               object
# bowling_team               object
# striker                    object
# non_striker                object
# bowler                     object
# runs_off_bat                int64
# extras                      int64
# wides                     float64
# noballs                   float64
# byes                      float64
# legbyes                   float64
# penalty                   float64
# wicket_type                object
# player_dismissed           object
# other_wicket_type         float64
# other_player_dismissed    float64
# dtype: object

# %%
data=data[(data.innings == 1) | (data.innings == 2)]

# %%
data.head(5)
# Out:
#    match_id  season  start_date                  venue  innings  ball  \
# 0    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   6.8
# 1    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   2.7
# 2    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.1
# 3    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.2
# 4    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.3
#
#                   batting_team           bowling_team     striker non_striker  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders  MV Boucher    CL White
# 1  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 2  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 3  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 4  Royal Challengers Bangalore  Kolkata Knight Riders   JH Kallis    W Jaffer
#
#    ... extras  wides  noballs  byes  legbyes  penalty  wicket_type  \
# ...

# %%
data.runs_off_bat.unique()
# Out:
# array([4, 1, 2, 0, 6, 5, 3], dtype=int64)

# %%
dot=data[data.runs_off_bat == 0]

# %%
dot.head(5)
# Out:
#     match_id  season  start_date                  venue  innings  ball  \
# 4     335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.3
# 5     335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.4
# 6     335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.5
# 7     335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.6
# 10    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   4.3
#
#                    batting_team           bowling_team    striker non_striker  \
# 4   Royal Challengers Bangalore  Kolkata Knight Riders  JH Kallis    W Jaffer
# 5   Royal Challengers Bangalore  Kolkata Knight Riders  JH Kallis    W Jaffer
# 6   Royal Challengers Bangalore  Kolkata Knight Riders   W Jaffer   JH Kallis
# 7   Royal Challengers Bangalore  Kolkata Knight Riders   W Jaffer   JH Kallis
# 10  Royal Challengers Bangalore  Kolkata Knight Riders  JH Kallis    W Jaffer
#
# ...

# %%
d1=dot.groupby('striker')['ball'].count().sort_values(ascending=False).head(10)
d1
# Out:
# striker
# S Dhawan      1958
# V Kohli       1886
# RG Sharma     1778
# CH Gayle      1634
# DA Warner     1633
# RV Uthappa    1598
# SK Raina      1475
# MS Dhoni      1370
# G Gambhir     1357
# AM Rahane     1341
# Name: ball, dtype: int64

# %%
d2=data.groupby('striker')['ball'].count().sort_values(ascending=False).head(10)
d2
# Out:
# striker
# V Kohli           5262
# S Dhawan          5081
# RG Sharma         4629
# DA Warner         4308
# SK Raina          4174
# RV Uthappa        3925
# MS Dhoni          3802
# G Gambhir         3524
# CH Gayle          3502
# AB de Villiers    3479
# Name: ball, dtype: int64

# %%
d1=pd.DataFrame(dot.groupby('striker')['ball'].count().sort_values(ascending=False)).reset_index()
d2=pd.DataFrame(data.groupby('striker')['ball'].count().sort_values(ascending=False)).reset_index()

# %%
d3=d1.merge(d2,on='striker')
d3.head(10)
# Out:
#       striker  ball_x  ball_y
# 0    S Dhawan    1958    5081
# 1     V Kohli    1886    5262
# 2   RG Sharma    1778    4629
# 3    CH Gayle    1634    3502
# 4   DA Warner    1633    4308
# 5  RV Uthappa    1598    3925
# 6    SK Raina    1475    4174
# 7    MS Dhoni    1370    3802
# 8   G Gambhir    1357    3524
# 9   AM Rahane    1341    3465

# %%
d3['dot']=(100*d3['ball_x']/d3['ball_y'])
d3=d3[(d3.ball_y >= 2000)]
d3
# Out:
#            striker  ball_x  ball_y        dot
# 0         S Dhawan    1958    5081  38.535721
# 1          V Kohli    1886    5262  35.841885
# 2        RG Sharma    1778    4629  38.410024
# 3         CH Gayle    1634    3502  46.659052
# 4        DA Warner    1633    4308  37.906221
# 5       RV Uthappa    1598    3925  40.713376
# 6         SK Raina    1475    4174  35.337805
# 7         MS Dhoni    1370    3802  36.033666
# 8        G Gambhir    1357    3524  38.507378
# 9        AM Rahane    1341    3465  38.701299
# 10       SR Watson    1247    2888  43.178670
# 11       AT Rayudu    1236    3375  36.622222
# 12      KD Karthik    1219    3383  36.033107
# 13       MK Pandey    1179    3102  38.007737
# 14  AB de Villiers    1113    3479  31.991952
# 15        PA Patel    1081    2442  44.266994
# 16        KL Rahul    1040    2927  35.531261
# 17     BB McCullum    1025    2267  45.213939
# 18         M Vijay     987    2208  44.701087
# ...

# %%
boun=data[(data.runs_off_bat == 4) | (data.runs_off_bat == 6)]
boun
# Out:
#         match_id  season  start_date                             venue  \
# 0         335982    2008  2008-04-18             M Chinnaswamy Stadium
# 11        335982    2008  2008-04-18             M Chinnaswamy Stadium
# 29        335982    2008  2008-04-18             M Chinnaswamy Stadium
# 30        335982    2008  2008-04-18             M Chinnaswamy Stadium
# 32        335982    2008  2008-04-18             M Chinnaswamy Stadium
# ...          ...     ...         ...                               ...
# 225913   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225922   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225924   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225937   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225952   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
#
#         innings  ball                 batting_team  \
# 0             2   6.8  Royal Challengers Bangalore
# ...

# %%
len(boun)
# Out:
# 36128

# %%
boun.dtypes
# Out:
# match_id                    int64
# season                      int64
# start_date                 object
# venue                      object
# innings                     int64
# ball                      float64
# batting_team               object
# bowling_team               object
# striker                    object
# non_striker                object
# bowler                     object
# runs_off_bat                int64
# extras                      int64
# wides                     float64
# noballs                   float64
# byes                      float64
# legbyes                   float64
# penalty                   float64
# wicket_type                object
# player_dismissed           object
# other_wicket_type         float64
# other_player_dismissed    float64
# dtype: object

# %%
b1=boun.groupby('striker')['runs_off_bat'].count().sort_values(ascending=False).head(10)
b1
# Out:
# striker
# S Dhawan          838
# V Kohli           798
# DA Warner         793
# CH Gayle          762
# RG Sharma         760
# SK Raina          709
# AB de Villiers    664
# RV Uthappa        663
# MS Dhoni          575
# SR Watson         566
# Name: runs_off_bat, dtype: int64

# %%
d2=data.groupby('striker')['ball'].count().sort_values(ascending=False).head(10)
d2
# Out:
# striker
# V Kohli           5262
# S Dhawan          5081
# RG Sharma         4629
# DA Warner         4308
# SK Raina          4174
# RV Uthappa        3925
# MS Dhoni          3802
# G Gambhir         3524
# CH Gayle          3502
# AB de Villiers    3479
# Name: ball, dtype: int64

# %%
b1=pd.DataFrame(boun.groupby('striker')['runs_off_bat'].count().sort_values(ascending=False)).reset_index()
d2=pd.DataFrame(data.groupby('striker')['ball'].count().sort_values(ascending=False)).reset_index()

# %%
b3=b1.merge(d2,on='striker')
b3
# Out:
#        striker  runs_off_bat  ball
# 0     S Dhawan           838  5081
# 1      V Kohli           798  5262
# 2    DA Warner           793  4308
# 3     CH Gayle           762  3502
# 4    RG Sharma           760  4629
# ..         ...           ...   ...
# 498  DR Shorey             1    20
# 499   DT Patil             1    13
# 500   FA Allen             1    19
# 501    RA Bawa             1    14
# 502   M Jansen             1    11
#
# [503 rows x 3 columns]

# %%
b3['boun']=(100*b3['runs_off_bat']/b3['ball'])
b3=b3[b3.ball > 2000]
b3
# Out:
#            striker  runs_off_bat  ball       boun
# 0         S Dhawan           838  5081  16.492816
# 1          V Kohli           798  5262  15.165336
# 2        DA Warner           793  4308  18.407614
# 3         CH Gayle           762  3502  21.758995
# 4        RG Sharma           760  4629  16.418233
# 5         SK Raina           709  4174  16.986104
# 6   AB de Villiers           664  3479  19.085944
# 7       RV Uthappa           663  3925  16.891720
# 8         MS Dhoni           575  3802  15.123619
# 9        SR Watson           566  2888  19.598338
# 10      KD Karthik           560  3383  16.553355
# 11       G Gambhir           551  3524  15.635641
# 12       AT Rayudu           513  3375  15.200000
# 13       AM Rahane           511  3465  14.747475
# 14        KL Rahul           491  2927  16.774855
# 15      KA Pollard           441  2433  18.125771
# 17       SV Samson           437  2663  16.410064
# 18    F du Plessis           424  2676  15.844544
# ...

# %%
combineddata=b3.merge(d3,on='striker')
combineddata
# Out:
#            striker  runs_off_bat  ball       boun  ball_x  ball_y        dot
# 0         S Dhawan           838  5081  16.492816    1958    5081  38.535721
# 1          V Kohli           798  5262  15.165336    1886    5262  35.841885
# 2        DA Warner           793  4308  18.407614    1633    4308  37.906221
# 3         CH Gayle           762  3502  21.758995    1634    3502  46.659052
# 4        RG Sharma           760  4629  16.418233    1778    4629  38.410024
# 5         SK Raina           709  4174  16.986104    1475    4174  35.337805
# 6   AB de Villiers           664  3479  19.085944    1113    3479  31.991952
# 7       RV Uthappa           663  3925  16.891720    1598    3925  40.713376
# 8         MS Dhoni           575  3802  15.123619    1370    3802  36.033666
# 9        SR Watson           566  2888  19.598338    1247    2888  43.178670
# 10      KD Karthik           560  3383  16.553355    1219    3383  36.033107
# ...

# %%
combineddata=combineddata.drop(['runs_off_bat','ball','ball_x','ball_y'],axis=1)

# %%
combineddata
# Out:
#            striker       boun        dot
# 0         S Dhawan  16.492816  38.535721
# 1          V Kohli  15.165336  35.841885
# 2        DA Warner  18.407614  37.906221
# 3         CH Gayle  21.758995  46.659052
# 4        RG Sharma  16.418233  38.410024
# 5         SK Raina  16.986104  35.337805
# 6   AB de Villiers  19.085944  31.991952
# 7       RV Uthappa  16.891720  40.713376
# 8         MS Dhoni  15.123619  36.033666
# 9        SR Watson  19.598338  43.178670
# 10      KD Karthik  16.553355  36.033107
# 11       G Gambhir  15.635641  38.507378
# 12       AT Rayudu  15.200000  36.622222
# 13       AM Rahane  14.747475  38.701299
# 14        KL Rahul  16.774855  35.531261
# 15      KA Pollard  18.125771  39.539663
# 16       SV Samson  16.410064  36.725498
# 17    F du Plessis  15.844544  36.472347
# 18     BB McCullum  18.659021  45.213939
# 19       MK Pandey  13.636364  38.007737
# 20       YK Pathan  18.068670  37.424893
# 21        PA Patel  16.953317  44.266994
# ...

# %%
x = combineddata['striker']
y = combineddata['boun']
  
# first plot with X and Y data
plt.plot(x, y)
  
x1 = combineddata['striker']
y1 = combineddata['dot']
  
# second plot with x1 and y1 data
plt.plot(x1, y1, '-.')
  
plt.xlabel("X-axis data")
plt.ylabel("Y-axis data")
plt.title('multiple plots')
plt.show()
