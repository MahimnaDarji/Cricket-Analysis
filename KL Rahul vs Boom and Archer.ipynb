# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('https://raw.githubusercontent.com/madaboutsports-mas/MAS-ACA-Masterclass/main/CSV%20Files/IPL_ball_by_ball_updated.csv?token=GHSAT0AAAAAAB6PBHSOIY6OOIDRRGBDEJKMZAPAE2A')

# %%
data.head(5)
# Out:
#    match_id  season  start_date                  venue  innings  ball  \
# 0    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   6.8
# 1    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   2.7
# 2    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.1
# 3    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.2
# 4    335982    2008  2008-04-18  M Chinnaswamy Stadium        2   3.3
#
#                   batting_team           bowling_team     striker non_striker  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders  MV Boucher    CL White
# 1  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 2  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 3  Royal Challengers Bangalore  Kolkata Knight Riders    W Jaffer   JH Kallis
# 4  Royal Challengers Bangalore  Kolkata Knight Riders   JH Kallis    W Jaffer
#
#    ... extras  wides  noballs  byes  legbyes  penalty  wicket_type  \
# ...

# %%
data.tail(5)
# Out:
#         match_id  season  start_date                             venue  \
# 225948   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225949   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225950   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225951   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 225952   1312200    2022  2022-05-29  Narendra Modi Stadium, Ahmedabad
#
#         innings  ball      batting_team      bowling_team       striker  \
# 225948        1  13.6  Rajasthan Royals    Gujarat Titans    SO Hetmyer
# 225949        1  14.1  Rajasthan Royals    Gujarat Titans    SO Hetmyer
# 225950        1  14.2  Rajasthan Royals    Gujarat Titans      R Ashwin
# 225951        1  12.2  Rajasthan Royals    Gujarat Titans      R Ashwin
# 225952        2  18.1    Gujarat Titans  Rajasthan Royals  Shubman Gill
#
#        non_striker  ... extras  wides  noballs  byes  legbyes  penalty  \
# ...

# %%
data.dtypes
# Out:
# match_id                    int64
# season                      int64
# start_date                 object
# venue                      object
# innings                     int64
# ball                      float64
# batting_team               object
# bowling_team               object
# striker                    object
# non_striker                object
# bowler                     object
# runs_off_bat                int64
# extras                      int64
# wides                     float64
# noballs                   float64
# byes                      float64
# legbyes                   float64
# penalty                   float64
# wicket_type                object
# player_dismissed           object
# other_wicket_type         float64
# other_player_dismissed    float64
# dtype: object

# %%
kld=data[data.striker == 'KL Rahul']
kld=kld[(kld.innings == 1) | (kld.innings == 2)]

# %%
kld.head()
# Out:
#        match_id  season  start_date                  venue  innings  ball  \
# 81397    598017    2013  2013-04-16  M Chinnaswamy Stadium        2   2.6
# 81398    598017    2013  2013-04-16  M Chinnaswamy Stadium        2   2.5
# 81399    598017    2013  2013-04-16  M Chinnaswamy Stadium        2   2.4
# 81400    598017    2013  2013-04-16  M Chinnaswamy Stadium        2   2.3
# 81401    598017    2013  2013-04-16  M Chinnaswamy Stadium        2   2.2
#
#                       batting_team      bowling_team   striker non_striker  \
# 81397  Royal Challengers Bangalore  Delhi Daredevils  KL Rahul    CH Gayle
# 81398  Royal Challengers Bangalore  Delhi Daredevils  KL Rahul    CH Gayle
# 81399  Royal Challengers Bangalore  Delhi Daredevils  KL Rahul    CH Gayle
# 81400  Royal Challengers Bangalore  Delhi Daredevils  KL Rahul    CH Gayle
# 81401  Royal Challengers Bangalore  Delhi Daredevils  KL Rahul    CH Gayle
#
# ...

# %%
bum=data[data.bowler == 'JJ Bumrah']
bum=bum[(bum.innings == 1)|(bum.innings == 2)]

# %%
bum.head()
# Out:
#        match_id  season  start_date                  venue  innings  ball  \
# 76740    597999    2013  2013-04-04  M Chinnaswamy Stadium        1   6.1
# 76741    597999    2013  2013-04-04  M Chinnaswamy Stadium        1   6.2
# 76742    597999    2013  2013-04-04  M Chinnaswamy Stadium        1   6.3
# 76743    597999    2013  2013-04-04  M Chinnaswamy Stadium        1   6.4
# 76744    597999    2013  2013-04-04  M Chinnaswamy Stadium        1   6.5
#
#                       batting_team    bowling_team       striker  \
# 76740  Royal Challengers Bangalore  Mumbai Indians    MA Agarwal
# 76741  Royal Challengers Bangalore  Mumbai Indians  DT Christian
# 76742  Royal Challengers Bangalore  Mumbai Indians  DT Christian
# 76743  Royal Challengers Bangalore  Mumbai Indians  DT Christian
# 76744  Royal Challengers Bangalore  Mumbai Indians      CH Gayle
#
#         non_striker  ... extras  wides  noballs  byes  legbyes  penalty  \
# ...

# %%
arc=data[data.bowler == 'JC Archer']
arc=arc[(arc.innings == 1)|(arc.innings == 2)]

# %%
arc.head()
# Out:
#         match_id  season  start_date                   venue  innings  ball  \
# 154922   1136581    2018  2018-04-22  Sawai Mansingh Stadium        1  12.6
# 154923   1136581    2018  2018-04-22  Sawai Mansingh Stadium        1  12.5
# 154924   1136581    2018  2018-04-22  Sawai Mansingh Stadium        1  12.4
# 154925   1136581    2018  2018-04-22  Sawai Mansingh Stadium        1  12.3
# 154926   1136581    2018  2018-04-22  Sawai Mansingh Stadium        1  12.2
#
#           batting_team      bowling_team       striker   non_striker  ...  \
# 154922  Mumbai Indians  Rajasthan Royals      SA Yadav  Ishan Kishan  ...
# 154923  Mumbai Indians  Rajasthan Royals  Ishan Kishan      SA Yadav  ...
# 154924  Mumbai Indians  Rajasthan Royals      SA Yadav  Ishan Kishan  ...
# 154925  Mumbai Indians  Rajasthan Royals      SA Yadav  Ishan Kishan  ...
# 154926  Mumbai Indians  Rajasthan Royals  Ishan Kishan      SA Yadav  ...
#
# ...

# %%
#Stats of KL Rahul in IPL
print("Total Runs Of KL in IPL",sum(kld['runs_off_bat']))
print("Balls Faced",len(kld))
print("Strike Rate Of KL",100*(sum(kld['runs_off_bat'])/len(kld)))
print("Average Of KL",(sum(kld['runs_off_bat'])/sum(kld.player_dismissed == 'KL Rahul')))
# Out:
# Total Runs Of KL in IPL 3889
# Balls Faced 2927
# Strike Rate Of KL 132.866416125726
# Average Of KL 49.22784810126582

# %%
#KL Rahul vs Bumrah
kvb=data[(data.striker == 'KL Rahul') & (data.bowler == 'JJ Bumrah')]
kvb=kvb[(kvb.innings == 1)|(kvb.innings == 2)]

# %%
kvb.head()
# Out:
#         match_id  season  start_date  \
# 102986    734001    2014  2014-05-12
# 102987    734001    2014  2014-05-12
# 102988    734001    2014  2014-05-12
# 102989    734001    2014  2014-05-12
# 102990    734001    2014  2014-05-12
#
#                                             venue  innings  ball  \
# 102986  Rajiv Gandhi International Stadium, Uppal        1   8.2
# 102987  Rajiv Gandhi International Stadium, Uppal        1   8.3
# 102988  Rajiv Gandhi International Stadium, Uppal        1   8.4
# 102989  Rajiv Gandhi International Stadium, Uppal        1   8.5
# 102990  Rajiv Gandhi International Stadium, Uppal        1   8.6
#
#                batting_team    bowling_team   striker non_striker  ... extras  \
# 102986  Sunrisers Hyderabad  Mumbai Indians  KL Rahul    AJ Finch  ...      0
# 102987  Sunrisers Hyderabad  Mumbai Indians  KL Rahul    AJ Finch  ...      0
# 102988  Sunrisers Hyderabad  Mumbai Indians  KL Rahul    AJ Finch  ...      0
# ...

# %%
#Kl vs Bumrah Stats Matchup
print("Total Runs Scored Vs Bumrah=",sum(kvb['runs_off_bat']))
print("Total Balls Faced=",len(kvb))
print("Strike Rate=",100*(sum(kvb['runs_off_bat'])/len(kvb)))
print("Average Of KL",(sum(kvb['runs_off_bat'])/sum(kvb.player_dismissed == 'KL Rahul')))
# Out:
# Total Runs Scored Vs Bumrah= 143
# Total Balls Faced= 117
# Strike Rate= 122.22222222222223
# Average Of KL 71.5

# %%
kvb[kvb.player_dismissed == 'KL Rahul']
# Out:
#         match_id  season  start_date                                venue  \
# 162119   1136610    2018  2018-05-16                     Wankhede Stadium
# 187595   1216517    2020  2020-10-18  Dubai International Cricket Stadium
#
#         innings  ball     batting_team    bowling_team   striker non_striker  \
# 162119        2  18.4  Kings XI Punjab  Mumbai Indians  KL Rahul    AR Patel
# 187595        2  17.3  Kings XI Punjab  Mumbai Indians  KL Rahul    DJ Hooda
#
#         ... extras  wides  noballs  byes  legbyes  penalty  wicket_type  \
# 162119  ...      0    NaN      NaN   NaN      NaN      NaN       caught
# 187595  ...      0    NaN      NaN   NaN      NaN      NaN       bowled
#
#         player_dismissed other_wicket_type other_player_dismissed
# 162119          KL Rahul               NaN                    NaN
# 187595          KL Rahul               NaN                    NaN
#
# [2 rows x 22 columns]

# %% [markdown]
# ### KL has got out to Boom only Twice, once bowled and one time caught

# %%
kva=data[(data.striker == 'KL Rahul')&(data.bowler == 'JC Archer')]
kva=kva[(kva.innings == 1) | (kva.innings == 2)]

# %%
kva.head(5)
# Out:
#         match_id  season  start_date                   venue  innings  ball  \
# 159113   1136598    2018  2018-05-06  Holkar Cricket Stadium        2  18.4
# 159146   1136598    2018  2018-05-06  Holkar Cricket Stadium        2  18.3
# 159147   1136598    2018  2018-05-06  Holkar Cricket Stadium        2  18.2
# 159148   1136598    2018  2018-05-06  Holkar Cricket Stadium        2  18.1
# 159156   1136598    2018  2018-05-06  Holkar Cricket Stadium        2  16.5
#
#            batting_team      bowling_team   striker non_striker  ... extras  \
# 159113  Kings XI Punjab  Rajasthan Royals  KL Rahul  MP Stoinis  ...      0
# 159146  Kings XI Punjab  Rajasthan Royals  KL Rahul  MP Stoinis  ...      0
# 159147  Kings XI Punjab  Rajasthan Royals  KL Rahul  MP Stoinis  ...      0
# 159148  Kings XI Punjab  Rajasthan Royals  KL Rahul  MP Stoinis  ...      0
# 159156  Kings XI Punjab  Rajasthan Royals  KL Rahul  MP Stoinis  ...      0
#
# ...

# %%
#KL vs Archer Stats Matchup
print("Runs by KL vs Archer=",sum(kva['runs_off_bat']))
print("Balls Faced by KL=",len(kva))
print("Strike Rate=",100*(sum(kva['runs_off_bat'])/len(kva)))
print("Average= Infinity(Because Not Dismissed by Archer even Once)")
# Out:
# Runs by KL vs Archer= 89
# Balls Faced by KL= 60
# Strike Rate= 148.33333333333334
# Average= Infinity(Because Not Dismissed by Archer even Once)

# %%
#Top 10 Batsmen with most runs vs Bumrah
b1=bum.groupby('striker')['runs_off_bat'].sum().sort_values(ascending = False).head(10)
b1
# Out:
# striker
# KL Rahul          143
# V Kohli           140
# AB de Villiers    125
# S Dhawan          105
# JP Duminy          70
# MK Pandey          69
# SPD Smith          68
# WP Saha            62
# KD Karthik         61
# F du Plessis       61
# Name: runs_off_bat, dtype: int64

# %%
b1=bum.groupby('striker')['runs_off_bat'].sum().sort_values(ascending = False).head(10).plot(kind='bar')
plt.title('Top 10 Batsmen with most runs vs Bumrah')
plt.xlabel('Player Name')
plt.ylabel('Total Runs')
plt.show()

# %%
#Players Dismissed most by Bumrah
b2=bum.groupby('striker')['player_dismissed'].count().sort_values(ascending=False).head(10)
b2
# Out:
# striker
# RR Pant        6
# GJ Maxwell     5
# AR Patel       4
# V Kohli        4
# MS Dhoni       4
# Rashid Khan    4
# DJ Bravo       4
# AD Russell     4
# SO Hetmyer     3
# MP Stoinis     3
# Name: player_dismissed, dtype: int64

# %%
b2=bum.groupby('striker')['player_dismissed'].count().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Players Dismissed most by Bumrah')
plt.xlabel('Player Name')
plt.ylabel('Times Dismissed')
plt.show()

# %%
#Most Balls Faced vs Bumrah
b3=bum.groupby('striker')['ball'].count().sort_values(ascending=False).head(10)
b3
# Out:
# striker
# KL Rahul          117
# V Kohli            93
# S Dhawan           89
# AB de Villiers     86
# MS Dhoni           64
# JC Buttler         58
# SPD Smith          57
# WP Saha            53
# CH Gayle           53
# SV Samson          49
# Name: ball, dtype: int64

# %%
b3=bum.groupby('striker')['ball'].count().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Most Balls Faced vs Bumrah')
plt.xlabel('Player Name')
plt.ylabel('Balls Faced')
plt.show()

# %%
b1=pd.DataFrame(bum.groupby('striker')['runs_off_bat'].sum().sort_values(ascending = False)).reset_index()
b2=pd.DataFrame(bum.groupby('striker')['player_dismissed'].count().sort_values(ascending = False)).reset_index()
b3=pd.DataFrame(bum.groupby('striker')['ball'].count().sort_values(ascending = False)).reset_index()

# %%
b4=b1.merge(b3,on='striker')
b4
# Out:
#             striker  runs_off_bat  ball
# 0          KL Rahul           143   117
# 1           V Kohli           140    93
# 2    AB de Villiers           125    86
# 3          S Dhawan           105    89
# 4         JP Duminy            70    33
# ..              ...           ...   ...
# 175    BE Hendricks             0     1
# 176         DR Sams             0     2
# 177          S Kaul             0     1
# 178       AJ Turner             0     1
# 179  Sandeep Sharma             0     1
#
# [180 rows x 3 columns]

# %%
b5=b4.merge(b2,on='striker')
b5.head(10)
# Out:
#           striker  runs_off_bat  ball  player_dismissed
# 0        KL Rahul           143   117                 2
# 1         V Kohli           140    93                 4
# 2  AB de Villiers           125    86                 3
# 3        S Dhawan           105    89                 1
# 4       JP Duminy            70    33                 1
# 5       MK Pandey            69    39                 0
# 6       SPD Smith            68    57                 3
# 7         WP Saha            62    53                 2
# 8      KD Karthik            61    35                 0
# 9    F du Plessis            61    38                 0

# %%
b4.reset_index(inplace=True,drop=True)
b5.reset_index(inplace=True,drop=True)

# %%
b5['StrikeRate']=100*(b5['runs_off_bat']/b5['ball'])
b5=b5[(b5.runs_off_bat > 30)]
b5
# Out:
#            striker  runs_off_bat  ball  player_dismissed  StrikeRate
# 0         KL Rahul           143   117                 2  122.222222
# 1          V Kohli           140    93                 4  150.537634
# 2   AB de Villiers           125    86                 3  145.348837
# 3         S Dhawan           105    89                 1  117.977528
# 4        JP Duminy            70    33                 1  212.121212
# 5        MK Pandey            69    39                 0  176.923077
# 6        SPD Smith            68    57                 3  119.298246
# 7          WP Saha            62    53                 2  116.981132
# 8       KD Karthik            61    35                 0  174.285714
# 9     F du Plessis            61    38                 0  160.526316
# 10        MS Dhoni            60    64                 4   93.750000
# 11       AT Rayudu            60    44                 2  136.363636
# 12         SS Iyer            59    40                 1  147.500000
# ...

# %%
plt.figure(figsize=(16,8))
plt.scatter(b5.runs_off_bat,b5.StrikeRate)

for i in range(len(b5)):
    plt.text(b5['runs_off_bat'][i],b5['StrikeRate'][i],b5['striker'][i])
plt.xlabel('Runs Scored')
plt.ylabel('StrikeRate')
plt.axvline(70,ls='--')
plt.axhline(130,ls='--')
plt.show()

# %% [markdown]
# ### KL Rahul's Stats vs Boom are pretty great only Virat and Abd has played better vs Boom then him

# %%
#Top 10 Batsmen with most runs vs Archer
a1=arc.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False).head(10)
a1
# Out:
# striker
# KL Rahul          89
# Q de Kock         48
# MS Dhoni          44
# KD Karthik        38
# HH Pandya         35
# AD Russell        34
# CH Gayle          32
# CA Lynn           32
# AB de Villiers    30
# MP Stoinis        30
# Name: runs_off_bat, dtype: int64

# %%
a1=arc.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Top 10 Batsmen with most runs vs Archer')
plt.xlabel('Player Name')
plt.ylabel('Total Runs')
plt.show()

# %%
#Players dismissed most by Archer
a2=arc.groupby('striker')['player_dismissed'].count().sort_values(ascending=False).head(10)
a2
# Out:
# striker
# CH Gayle         3
# AT Rayudu        2
# F du Plessis     2
# KD Karthik       2
# KH Pandya        2
# DA Warner        2
# RG Sharma        2
# Shubman Gill     2
# PP Shaw          2
# Mandeep Singh    2
# Name: player_dismissed, dtype: int64

# %%
a2=arc.groupby('striker')['player_dismissed'].count().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Players Dismissed most by Archer')
plt.xlabel('Player Name')
plt.ylabel('Times Dismissed')
plt.show()

# %%
#Most Balls Faced vs Archer
a3=arc.groupby('striker')['ball'].count().sort_values(ascending=False).head(10)
a3
# Out:
# striker
# KL Rahul      60
# MS Dhoni      38
# HH Pandya     31
# Q de Kock     30
# KD Karthik    27
# CH Gayle      26
# AD Russell    23
# SA Yadav      23
# CA Lynn       21
# MP Stoinis    21
# Name: ball, dtype: int64

# %%
a3=arc.groupby('striker')['ball'].count().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Most Balls Faced vs Archer')
plt.xlabel('Player Name')
plt.ylabel('Balls Faced')
plt.show()

# %%
a1=pd.DataFrame(arc.groupby('striker')['runs_off_bat'].sum().sort_values(ascending=False)).reset_index()
a2=pd.DataFrame(arc.groupby('striker')['player_dismissed'].count().sort_values(ascending=False)).reset_index()
a3=pd.DataFrame(arc.groupby('striker')['ball'].count().sort_values(ascending=False)).reset_index()

# %%
a4=a1.merge(a3,on='striker')
a4.shape
# Out:
# (79, 3)

# %%
a5=a4.merge(a2,on='striker')
a5.head()
# Out:
#       striker  runs_off_bat  ball  player_dismissed
# 0    KL Rahul            89    60                 0
# 1   Q de Kock            48    30                 2
# 2    MS Dhoni            44    38                 0
# 3  KD Karthik            38    27                 2
# 4   HH Pandya            35    31                 2

# %%
a4.reset_index(inplace=True,drop=True)
a5.reset_index(inplace=True,drop=True)

# %%
a5['StrikeRate']=100*(a5['runs_off_bat']/a5['ball'])
a5=a5[(a5.runs_off_bat>10)]
a5
# Out:
#            striker  runs_off_bat  ball  player_dismissed  StrikeRate
# 0         KL Rahul            89    60                 0  148.333333
# 1        Q de Kock            48    30                 2  160.000000
# 2         MS Dhoni            44    38                 0  115.789474
# 3       KD Karthik            38    27                 2  140.740741
# 4        HH Pandya            35    31                 2  112.903226
# 5       AD Russell            34    23                 0  147.826087
# 6         CH Gayle            32    26                 3  123.076923
# 7          CA Lynn            32    21                 0  152.380952
# 8   AB de Villiers            30    13                 0  230.769231
# 9       MP Stoinis            30    21                 1  142.857143
# 10        PA Patel            28    14                 1  200.000000
# 11       V Shankar            27    19                 0  142.105263
# 12   KS Williamson            27    15                 0  180.000000
# ...

# %%
plt.figure(figsize=(16,8))
plt.scatter(a5.runs_off_bat,a5.StrikeRate)
for i in range(len(a5)):
    plt.text(a5['runs_off_bat'][i],a5['StrikeRate'][i],a5['striker'][i])
plt.xlabel('Runs Scored')
plt.ylabel('Strike Rate')
plt.axvline(30,ls='--')
plt.axhline(130,ls='--')
plt.show()

# %% [markdown]
# ### KL Rahul has performed the best vs Archer in IPL

# %%
k1=kld.groupby('bowler')['runs_off_bat'].sum().sort_values(ascending=False).head(10)
k1
# Out:
# bowler
# JJ Bumrah          143
# DL Chahar          120
# JD Unadkat         112
# SP Narine          105
# B Kumar             93
# Mohammed Siraj      91
# JC Archer           89
# YS Chahal           87
# Harbhajan Singh     81
# HH Pandya           80
# Name: runs_off_bat, dtype: int64

# %%
k1=kld.groupby('bowler')['runs_off_bat'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Runs KL has scored most against')
plt.xlabel('Player Name')
plt.ylabel('Total Runs')
plt.show()

# %%
k2=kld.groupby('bowler')['player_dismissed'].count().sort_values(ascending=False).head(10)
k2
# Out:
# bowler
# DS Kulkarni          4
# Harbhajan Singh      3
# Rashid Khan          3
# C Sakariya           2
# MM Sharma            2
# MJ McClenaghan       2
# M Prasidh Krishna    2
# L Ngidi              2
# PP Chawla            2
# K Rabada             2
# Name: player_dismissed, dtype: int64

# %%
k2=kld.groupby('bowler')['player_dismissed'].count().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Bowlers Dismissed KL Most')
plt.xlabel('Player Name')
plt.ylabel('Times Dismissed')
plt.show()

# %%
k3=kld.groupby('bowler')['ball'].count().sort_values(ascending=False).head(10)
k3
# Out:
# bowler
# JJ Bumrah         117
# B Kumar            80
# DL Chahar          79
# KH Pandya          75
# SP Narine          70
# JD Unadkat         65
# Sandeep Sharma     63
# UT Yadav           62
# YS Chahal          60
# JC Archer          60
# Name: ball, dtype: int64

# %%
k3=kld.groupby('bowler')['ball'].count().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Bowlers Faced Most')
plt.xlabel('Player Name')
plt.ylabel('Balls Faced')
plt.show()

# %%
k1=pd.DataFrame(kld.groupby('bowler')['runs_off_bat'].sum().sort_values(ascending=False)).reset_index()
k2=pd.DataFrame(kld.groupby('bowler')['player_dismissed'].count().sort_values(ascending=False)).reset_index()
k3=pd.DataFrame(kld.groupby('bowler')['ball'].count().sort_values(ascending=False)).reset_index()

# %%
k4=k1.merge(k3,on='bowler')
k4
# Out:
#              bowler  runs_off_bat  ball
# 0         JJ Bumrah           143   117
# 1         DL Chahar           120    79
# 2        JD Unadkat           112    65
# 3         SP Narine           105    70
# 4           B Kumar            93    80
# ..              ...           ...   ...
# 150        MA Starc             0     1
# 151     LH Ferguson             0     4
# 152   CR Brathwaite             0     1
# 153     D Pretorius             0     1
# 154  Arshdeep Singh             0     5
#
# [155 rows x 3 columns]

# %%
k5=k4.merge(k2,on='bowler')
k5
# Out:
#              bowler  runs_off_bat  ball  player_dismissed
# 0         JJ Bumrah           143   117                 2
# 1         DL Chahar           120    79                 0
# 2        JD Unadkat           112    65                 1
# 3         SP Narine           105    70                 2
# 4           B Kumar            93    80                 1
# ..              ...           ...   ...               ...
# 150        MA Starc             0     1                 0
# 151     LH Ferguson             0     4                 1
# 152   CR Brathwaite             0     1                 1
# 153     D Pretorius             0     1                 1
# 154  Arshdeep Singh             0     5                 0
#
# [155 rows x 4 columns]

# %%
k5['StrikeRate']=100*(k5['runs_off_bat']/k5['ball'])
k5=k5[(k5.ball > 40)]
k5
# Out:
#              bowler  runs_off_bat  ball  player_dismissed  StrikeRate
# 0         JJ Bumrah           143   117                 2  122.222222
# 1         DL Chahar           120    79                 0  151.898734
# 2        JD Unadkat           112    65                 1  172.307692
# 3         SP Narine           105    70                 2  150.000000
# 4           B Kumar            93    80                 1  116.250000
# 5    Mohammed Siraj            91    48                 0  189.583333
# 6         JC Archer            89    60                 0  148.333333
# 7         YS Chahal            87    60                 2  145.000000
# 8   Harbhajan Singh            81    54                 3  150.000000
# 9         HH Pandya            80    48                 0  166.666667
# 10         TA Boult            80    51                 2  156.862745
# 11         UT Yadav            78    62                 1  125.806452
# ...

# %%
k4.reset_index(inplace=True,drop=True)
k5.reset_index(inplace=True,drop=True)

# %%
plt.figure(figsize=(16,8))
plt.scatter(k5.runs_off_bat,k5.StrikeRate)

for i in range(len(k5)):
    plt.text(k5['runs_off_bat'][i],k5['StrikeRate'][i],k5['bowler'][i])
plt.title('KL Against Bowlers who he faced more than 40 Balls')
plt.xlabel('Runs')
plt.ylabel('Strike Rate')
plt.axvline(70,ls='--')
plt.axhline(130,ls='--')
plt.show()
