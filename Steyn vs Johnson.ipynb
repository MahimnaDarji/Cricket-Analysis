# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv('https://raw.githubusercontent.com/madaboutsports-mas/MAS-ACA-Masterclass/main/CSV%20Files/ODI_data.csv?token=GHSAT0AAAAAAB6PBHSOICIY4RCPLG7TIUC2Y757DEQ')

# %%
data.head(5)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0        E Lewis                  65                      65
# 1       N Pooran                  42                      42
# 2     SO Hetmyer                  18                      18
# 3       RL Chase                  18                      18
# 4    SS Cottrell                  17                      17
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    128                  1.0                   0.0
# 1                     69                  1.0                   0.0
# 2                     31                  1.0                   0.0
# 3                     34                  1.0                   0.0
# 4                     23                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                  80                      8                      1
# ...

# %%
data.tail(5)
# Out:
#        Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 171963     IR Redpath                 NaN                     NaN
# 171964    IM Chappell                 NaN                     NaN
# 171965     KD Walters                 NaN                     NaN
# 171966       RW Marsh                 NaN                     NaN
# 171967    GS Chappell                 NaN                     NaN
#
#        Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 171963                    NaN                  NaN                   NaN
# 171964                    NaN                  NaN                   NaN
# 171965                    NaN                  NaN                   NaN
# 171966                    NaN                  NaN                   NaN
# 171967                    NaN                  NaN                   NaN
#
#        Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# ...

# %%
data['Innings Wickets Taken'].unique()
# Out:
# array([nan, '3', '1', '0', '-', '4', '2', '6', '5', '7', '8'],
#       dtype=object)

# %%
data=data[data['Innings Wickets Taken'] != '-']

# %%
data['Innings Wickets Taken'].unique()
# Out:
# array([nan, '3', '1', '0', '4', '2', '6', '5', '7', '8'], dtype=object)

# %%
data=data.dropna(subset=['Innings Wickets Taken'])

# %%
data['Innings Wickets Taken'].unique()
# Out:
# array(['3', '1', '0', '4', '2', '6', '5', '7', '8'], dtype=object)

# %%
data['Innings Date']=pd.to_datetime(data['Innings Date'])

# %%
data['Year']=data['Innings Date'].dt.year

# %%
data.head(2)
# Out:
#    Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 22  CR Brathwaite                 NaN                     NaN
# 23       RL Chase                 NaN                     NaN
#
#    Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 22                    NaN                  NaN                   NaN
# 23                    NaN                  NaN                   NaN
#
#    Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 22                 NaN                    NaN                    NaN
# 23                 NaN                    NaN                    NaN
#
#    Innings Batting Strike Rate  ... Innings Bowled Flag  \
# 22                         NaN  ...                 1.0
# 23                         NaN  ...                 1.0
#
#    Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  \
# 22                      0                    53                     3
# ...

# %%
data['Innings Overs Bowled']=data['Innings Overs Bowled'].astype(float)

# %%
data['Innings Maidens Bowled']=data['Innings Maidens Bowled'].astype(int)

# %%
data['Innings Runs Conceded']=data['Innings Runs Conceded'].astype(int)

# %%
data['Innings Wickets Taken']=data['Innings Wickets Taken'].astype(int)

# %%
data['Innings Overs Bowled']=data['Innings Overs Bowled'].astype(int)

# %%
data['Innings Overs Bowled']=data['Innings Overs Bowled'].astype(int)

# %%
data.dtypes
# Out:
# Innings Player                           object
# Innings Runs Scored                      object
# Innings Runs Scored Num                  object
# Innings Minutes Batted                   object
# Innings Batted Flag                     float64
# Innings Not Out Flag                    float64
# Innings Balls Faced                      object
# Innings Boundary Fours                   object
# Innings Boundary Sixes                   object
# Innings Batting Strike Rate              object
# Innings Number                           object
# Opposition                               object
# Ground                                   object
# Innings Date                     datetime64[ns]
# Country                                  object
# 50's                                    float64
# 100's                                   float64
# Innings Runs Scored Buckets              object
# Innings Overs Bowled                      int32
# Innings Bowled Flag                     float64
# ...

# %%
johnson_data=data[(data.Year >= 2005) & (data.Year <= 2015)]

# %%
johnson_data.head(5)
# Out:
#        Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 18920  MJ McClenaghan                 NaN                     NaN
# 18921      MJ Guptill                 NaN                     NaN
# 18922   KS Williamson                 NaN                     NaN
# 18923      TG Southee                 NaN                     NaN
# 18924   DAJ Bracewell                 NaN                     NaN
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 18920                    NaN                  NaN                   NaN
# 18921                    NaN                  NaN                   NaN
# 18922                    NaN                  NaN                   NaN
# 18923                    NaN                  NaN                   NaN
# 18924                    NaN                  NaN                   NaN
#
#       Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# ...

# %%
steyn_data=data[(data.Year >= 2005) & (data.Year <= 2019)]

# %%
steyn_data.head(5)
# Out:
#    Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 22  CR Brathwaite                 NaN                     NaN
# 23       RL Chase                 NaN                     NaN
# 24    SS Cottrell                 NaN                     NaN
# 25      JO Holder                 NaN                     NaN
# 26       O Thomas                 NaN                     NaN
#
#    Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 22                    NaN                  NaN                   NaN
# 23                    NaN                  NaN                   NaN
# 24                    NaN                  NaN                   NaN
# 25                    NaN                  NaN                   NaN
# 26                    NaN                  NaN                   NaN
#
#    Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 22                 NaN                    NaN                    NaN
# ...

# %%
mj=johnson_data[johnson_data['Innings Player'] == 'MG Johnson']

# %%
mj.head(5)
# Out:
#       Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 21956     MG Johnson                 NaN                     NaN
# 22002     MG Johnson                 NaN                     NaN
# 22136     MG Johnson                 NaN                     NaN
# 22343     MG Johnson                 NaN                     NaN
# 22640     MG Johnson                 NaN                     NaN
#
#       Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 21956                    NaN                  NaN                   NaN
# 22002                    NaN                  NaN                   NaN
# 22136                    NaN                  NaN                   NaN
# 22343                    NaN                  NaN                   NaN
# 22640                    NaN                  NaN                   NaN
#
#       Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# ...

# %%
ds=steyn_data[steyn_data['Innings Player'] == 'DW Steyn']

# %%
ds.head(5)
# Out:
#      Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 3447       DW Steyn                 NaN                     NaN
# 4470       DW Steyn                 NaN                     NaN
# 4557       DW Steyn                 NaN                     NaN
# 4642       DW Steyn                 NaN                     NaN
# 5248       DW Steyn                 NaN                     NaN
#
#      Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 3447                    NaN                  NaN                   NaN
# 4470                    NaN                  NaN                   NaN
# 4557                    NaN                  NaN                   NaN
# 4642                    NaN                  NaN                   NaN
# 5248                    NaN                  NaN                   NaN
#
#      Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 3447                 NaN                    NaN                    NaN
# ...

# %%
#Total Matches Played
print("Total Matches Played By Johnson",print("Total Matches Played By Johnson",sum(mj['Innings Bowled Flag'])))
print("Total Matches Played By Steyn",sum(ds['Innings Bowled Flag']))
# Out:
# Total Matches Played By Johnson 150.0
# Total Matches Played By Steyn 122.0

# %%
#Total Wickets Taken By Both
print("Total Wickets Of Johnson",sum(mj['Innings Wickets Taken']))
print("Total Wickets Of Steyn",sum(ds['Innings Wickets Taken']))
# Out:
# Total Wickets Of Johnson 239
# Total Wickets Of Steyn 194

# %%
#Wickets Per Innings
print("WPI Of Johnson",(sum(mj['Innings Wickets Taken'])/sum(mj['Innings Bowled Flag'])))
print("WPI Of Steyn",(sum(ds['Innings Wickets Taken'])/sum(ds['Innings Bowled Flag'])))
# Out:
# WPI Of Johnson 1.5933333333333333
# WPI Of Steyn 1.5901639344262295

# %%
#Career Economy Rate
print("Economy Rate Of Johnson",(sum(mj['Innings Runs Conceded'])/sum(mj['Innings Overs Bowled'])))
print("Economy Rate Of Steyn",(sum(ds['Innings Runs Conceded'])/sum(ds['Innings Overs Bowled'])))
# Out:
# Economy Rate Of Johnson 4.865431103948429
# Economy Rate Of Steyn 4.9315738025415445

# %%
#Maiden Overs
print("Total Maiden Overs Bowled By Johnson",sum(mj['Innings Maidens Bowled']))
print("Total Maiden Overs Bowled By Steyn",sum(ds['Innings Maidens Bowled']))
print("Number Of Maidens per Over of Johnson",sum(mj['Innings Overs Bowled'])/sum(mj['Innings Maidens Bowled']))
print("Number Of Maidens per Over of Steyn",sum(ds['Innings Overs Bowled'])/sum(ds['Innings Maidens Bowled']))
# Out:
# Total Maiden Overs Bowled By Johnson 74
# Total Maiden Overs Bowled By Steyn 69
# Number Of Maidens per Over of Johnson 16.77027027027027
# Number Of Maidens per Over of Steyn 14.826086956521738

# %%
#Bowling Average
print("Bowling Average of Johnson",(sum(mj['Innings Runs Conceded'])/sum(mj['Innings Wickets Taken'])))
print("Bowling Average of Steyn",(sum(ds['Innings Runs Conceded'])/sum(ds['Innings Wickets Taken'])))
# Out:
# Bowling Average of Johnson 25.263598326359833
# Bowling Average of Steyn 26.00515463917526

# %%
#Contribution in their Teams Wickets
print("Total Wickets Taken By Australia During Johnson's Career",(sum(johnson_data[johnson_data.Country == 'Australia']['Innings Wickets Taken'])))
print("Total Wickets Taken By Johnson in his Career",sum(mj['Innings Wickets Taken']))
print("Contribution Of Johnson in Team's Wickets",(100*sum(mj['Innings Wickets Taken']))/(sum(johnson_data[johnson_data.Country == 'Australia']['Innings Wickets Taken'])),"%")
# Out:
# Total Wickets Taken By Australia During Johnson's Career 2088
# Total Wickets Taken By Johnson in his Career 239
# Contribution Of Johnson in Team's Wickets 11.446360153256705 %

# %%
print("Total Wickets Taken By Soth Africa During Steyn's Career",(sum(steyn_data[steyn_data.Country == 'South Africa']['Innings Wickets Taken'])))
print("Total Wickets Taken By Steyn in his Career",sum(ds['Innings Wickets Taken']))
print("Contribution Of Steyn in Team's Wickets",(100*sum(ds['Innings Wickets Taken']))/(sum(johnson_data[johnson_data.Country == 'South Africa']['Innings Wickets Taken'])),"%")
# Out:
# Total Wickets Taken By Soth Africa During Steyn's Career 2185
# Total Wickets Taken By Steyn in his Career 194
# Contribution Of Steyn in Team's Wickets 11.658653846153847 %

# %% [markdown]
# # Visualization Part

# %%
#Performance Of Other Player in their time
steyn_data.groupby(['Innings Player'])['Innings Wickets Taken'].sum().sort_values(ascending = False).head(15)
# Out:
# Innings Player
# SL Malinga          334
# Shakib Al Hasan     260
# Mashrafe Mortaza    250
# Shahid Afridi       240
# MG Johnson          239
# B Lee               220
# JM Anderson         210
# Abdur Razzak        201
# KMDN Kulasekara     196
# DW Steyn            194
# KD Mills            193
# TG Southee          186
# Saeed Ajmal         184
# M Morkel            180
# SCJ Broad           178
# Name: Innings Wickets Taken, dtype: int32

# %%
steyn_data.groupby(['Innings Player'])['Innings Wickets Taken'].sum().sort_values(ascending = False).head(15).plot(kind='bar')
plt.xlabel('Total Wickets')
plt.ylabel('Players')
plt.show()

# %%
steyn_data.groupby(['Innings Player'])['Innings Maidens Bowled'].sum().sort_values(ascending = False).head(15)
# Out:
# Innings Player
# Mashrafe Mortaza    111
# KD Mills            103
# KMDN Kulasekara     101
# SL Malinga          100
# SM Pollock           97
# JM Anderson          94
# Shakib Al Hasan      83
# B Lee                81
# MG Johnson           74
# TG Southee           72
# NW Bracken           72
# Z Khan               69
# DW Steyn             69
# B Kumar              67
# Abdur Razzak         66
# Name: Innings Maidens Bowled, dtype: int32

# %%
steyn_data.groupby(['Innings Player'])['Innings Maidens Bowled'].sum().sort_values(ascending = False).head(15).plot(kind='bar')
plt.xlabel('Total Maiden Overs')
plt.ylabel('Players')
plt.show()
